# %% [markdown]
#  数据集 BT-TWD 可行性实验
#
# 本 notebook 按步骤运行：加载配置 → 读取数据 → 预处理 → 桶树划分 → 基线与 BTTWD k 折实验 → 桶级分析。

# %%
# 步骤0：环境与路径设置
import os, sys
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
plt.rcParams['axes.unicode_minus'] = False

# 将项目根目录加入路径，便于导入 bttwdlib
root_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
if root_path not in sys.path:
    sys.path.append(root_path)

from bttwdlib import (
    load_yaml_cfg,
    show_cfg,
    load_dataset,
    prepare_features_and_labels,
    BucketTree,
    run_kfold_experiments,
    log_info,
    set_global_seed,
)

cfg_path = os.path.join(root_path, 'configs', 'adult_bttwd.yaml')
cfg = load_yaml_cfg(cfg_path)
set_global_seed(cfg.get('SEED', {}).get('global_seed', 42))
log_info('【步骤0摘要】环境准备完毕，路径与随机种子已设置。')
# Out:
# 【INFO】【2026-03-26 15:25:04】【配置加载】已读取 e:\yan\组\三支决策\机器学习\BT_TWD\configs\adult_bttwd.yaml
# 【INFO】【2026-03-26 15:25:13】【步骤0摘要】环境准备完毕，路径与随机种子已设置。

# %%
# 步骤1：加载配置
show_cfg(cfg)
log_info('【步骤1摘要】配置文件加载完成，关键参数检查通过。')
# Out:
# 【INFO】【2026-03-26 15:25:13】【配置-数据】数据集=adult, k折=5, 目标列=income, 正类=">50K"
# 【INFO】【2026-03-26 15:25:13】【配置-BTTWD】阈值模式=None, 全局模型=xgb, 桶内模型=none, 后验估计器(兼容字段)=logreg
# 【INFO】【2026-03-26 15:25:13】【配置-基线】LogReg启用=True, RandomForest启用=True, KNN启用=True, XGBoost启用=True
# 【INFO】【2026-03-26 15:25:13】【步骤1摘要】配置文件加载完成，关键参数检查通过。

# %%
# 步骤2：加载原始数据
df_raw, target_col_model = load_dataset(cfg)  # 这里返回的是用于建模的标签列，例如 "label"

display(df_raw.head())
print("用于建模的标签列:", target_col_model)

# 1）画 0/1 标签（延误/不延误）的比例
class_counts = df_raw[target_col_model].value_counts(normalize=True)
ax = class_counts.plot(kind='bar', title='延误 vs 未延误比例')
plt.ylabel('比例')

fig_path = os.path.join(root_path, cfg['OUTPUT']['figs_dir'], 'class_distribution.png')
os.makedirs(os.path.dirname(fig_path), exist_ok=True)
plt.savefig(fig_path, bbox_inches='tight')
plt.close()

# 2）如果想看原始 DepDelay 的分布，可以另外单独分析：
raw_target_col = cfg['DATA']['target_col']  # 这里是 "DepDelay"
print("原始目标列:", raw_target_col)
print(df_raw[raw_target_col].describe())

log_info('【步骤2摘要】Airlines 原始数据加载与基本统计完成。')
# Out:
# 【INFO】【2026-03-26 15:25:13】【数据加载完毕】样本数=32561，特征数=14，正类比例=0.24
# 【INFO】【2026-03-26 15:25:13】【数据加载】24720 条标签无法映射，未指定负类且未开启 dropna_target，已按 0 处理
# 【INFO】【2026-03-26 15:25:13】【数据加载】标签列 income 已处理完成：dropna_target=False, 丢弃样本=0, 最终样本数=32561, 正类比例=24.08%
# 【INFO】【2026-03-26 15:25:13】【数据集信息】名称=adult，样本数=32561，目标列=income，正类比例=24.08%
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country  income
# 0          2174             0              40  United-States       0
# 1             0             0              13  United-States       0
# 2             0             0              40  United-States       0
# 3             0             0              40  United-States       0
# 4             0             0              40           Cuba       0
# 用于建模的标签列: income
# 原始目标列: income
# count    32561.000000
# mean         0.240810
# std          0.427581
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: income, dtype: float64
# 【INFO】【2026-03-26 15:25:13】【步骤2摘要】Airlines 原始数据加载与基本统计完成。

# %%
# 步骤3：预处理与特征工程
X, y, meta = prepare_features_and_labels(df_raw, cfg)
log_info(f'【预处理】编码特征维度={X.shape[1]}，样本数={X.shape[0]}')
log_info(f"【步骤3摘要】特征预处理完成：连续={len(meta['continuous_cols'])}，类别={len(meta['categorical_cols'])}，编码维度={X.shape[1]}。")
# Out:
# 【INFO】【2026-03-26 15:25:13】【预处理】连续特征=6个，类别特征=8个
# 【INFO】【2026-03-26 15:25:13】【预处理】编码后维度=100
# 【INFO】【2026-03-26 15:25:13】【预处理】编码特征维度=100，样本数=32561
# 【INFO】【2026-03-26 15:25:13】【步骤3摘要】特征预处理完成：连续=6，类别=8，编码维度=100。

# %%
# 步骤4：构建桶树并检查划分
bucket_tree = BucketTree(cfg['BTTWD']['bucket_levels'], feature_names=df_raw.drop(columns=[cfg['DATA']['target_col']]).columns.tolist())
bucket_ids_full = bucket_tree.assign_buckets(df_raw.drop(columns=[cfg['DATA']['target_col']]))
bucket_df = bucket_ids_full.value_counts().reset_index()
bucket_df.columns = ['bucket_id', 'count']
bucket_df['pos_rate'] = df_raw.groupby(bucket_ids_full)[cfg['DATA']['target_col']].apply(lambda s: (s == cfg['DATA']['positive_label']).mean()).values
display(bucket_df.head())
bucket_df.set_index('bucket_id')['count'].plot(kind='bar', figsize=(12,4), title='桶样本数分布')
fig_bucket = os.path.join(root_path, cfg['OUTPUT']['figs_dir'], 'bucket_metrics_bar.png')
plt.savefig(fig_bucket, bbox_inches='tight')
plt.close()
log_info(f'【步骤4摘要】桶树划分完成，共有 {bucket_ids_full.nunique()} 个叶子桶。')
# Out:
# 【INFO】【2026-03-26 15:25:13】【桶树】已为样本生成桶ID，共 48 个组合
#                                            bucket_id  count  pos_rate
# 0  L1_age=old|L2_education=high|L3_hours-per-week...   3211       0.0
# 1  L1_age=old|L2_education=mid|L3_hours-per-week=...   2713       0.0
# 2  L1_age=mid|L2_education=high|L3_hours-per-week...   2584       0.0
# 3  L1_age=mid|L2_education=mid|L3_hours-per-week=...   2321       0.0
# 4  L1_age=very_old|L2_education=mid|L3_hours-per-...   1654       0.0
# 【INFO】【2026-03-26 15:25:14】【步骤4摘要】桶树划分完成，共有 48 个叶子桶。

# %%
# 步骤5：运行基线模型 k 折实验
# 基线部分在 run_kfold_experiments 内统一调度
log_info('【步骤5】基线模型将在整体交叉验证中一并运行。')
log_info('【步骤5摘要】基线模型性能将作为后续对比基准。')
# Out:
# 【INFO】【2026-03-26 15:25:14】【步骤5】基线模型将在整体交叉验证中一并运行。
# 【INFO】【2026-03-26 15:25:14】【步骤5摘要】基线模型性能将作为后续对比基准。

# %%
import numpy as np
import pandas as pd

print("y 全局标签分布：", np.unique(y, return_counts=True))

print("原始 income 列分布：")
print(df_raw[cfg['DATA']['target_col']].value_counts())
# Out:
# y 全局标签分布： (array([0, 1]), array([24720,  7841], dtype=int64))
# 原始 income 列分布：
# income
# 0    24720
# 1     7841
# Name: count, dtype: int64

# %%
# 步骤6：运行 BTTWD k 折实验（含基线）
results = run_kfold_experiments(X, y, df_raw.drop(columns=[cfg['DATA']['target_col']]), cfg)
summary_df = pd.read_csv(os.path.join(root_path, cfg['OUTPUT']['results_dir'], 'metrics_kfold_summary.csv'))
display(summary_df)
summary_df.plot(x='model', kind='bar', figsize=(8,4), title='模型指标对比')
fig_compare = os.path.join(root_path, cfg['OUTPUT']['figs_dir'], 'metrics_compare.png')
plt.savefig(fig_compare, bbox_inches='tight')
plt.close()
log_info('【步骤6摘要】BTTWD 与基线的 k 折结果已生成并保存。')
# Out:
# 【INFO】【2026-03-26 15:25:14】【基线-LogReg】使用决策阈值=0.400（fixed 模式）
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\baselines.py:109: RuntimeWarning: Mean of empty slice
#   summary[f"{col}_mean"] = float(np.nanmean(arr))
# d:\Anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# 【INFO】【2026-03-26 15:25:22】【基线-LogReg】整体指标：AUC_mean=0.907, AUC_std=0.002, BAC_mean=0.795, BAC_std=0.002, BND_ratio_mean=0.000, BND_ratio_std=0.000, F1_mean=0.687, F1_std=0.004, Kappa_mean=0.586, Kappa_std=0.006, MCC_mean=0.586, MCC_std=0.005, POS_Coverage_mean=nan, POS_Coverage_std=nan, Precision_mean=0.679, Precision_std=0.008, Recall_mean=0.695, Recall_std=0.007, Regret_mean=0.170, Regret_std=0.002
# 【INFO】【2026-03-26 15:25:22】【基线-RF】使用决策阈值=0.400（fixed 模式）
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\baselines.py:109: RuntimeWarning: Mean of empty slice
#   summary[f"{col}_mean"] = float(np.nanmean(arr))
# d:\Anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# 【INFO】【2026-03-26 15:25:30】【基线-RF】整体指标：AUC_mean=0.906, AUC_std=0.002, BAC_mean=0.804, BAC_std=0.006, BND_ratio_mean=0.000, BND_ratio_std=0.000, F1_mean=0.696, F1_std=0.008, Kappa_mean=0.596, Kappa_std=0.010, MCC_mean=0.596, MCC_std=0.011, POS_Coverage_mean=nan, POS_Coverage_std=nan, Precision_mean=0.676, Precision_std=0.007, Recall_mean=0.717, Recall_std=0.011, Regret_mean=0.164, Regret_std=0.005
# 【INFO】【2026-03-26 15:25:30】【基线-KNN】使用决策阈值=0.400（fixed 模式）
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\baselines.py:109: RuntimeWarning: Mean of empty slice
#   summary[f"{col}_mean"] = float(np.nanmean(arr))
# d:\Anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [15:25:33] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 【INFO】【2026-03-26 15:25:33】【基线-KNN】整体指标：AUC_mean=0.869, AUC_std=0.006, BAC_mean=0.780, BAC_std=0.008, BND_ratio_mean=0.000, BND_ratio_std=0.000, F1_mean=0.657, F1_std=0.011, Kappa_mean=0.543, Kappa_std=0.015, MCC_mean=0.544, MCC_std=0.015, POS_Coverage_mean=nan, POS_Coverage_std=nan, Precision_mean=0.631, Precision_std=0.011, Recall_mean=0.687, Recall_std=0.014, Regret_mean=0.186, Regret_std=0.007
# 【INFO】【2026-03-26 15:25:33】【基线-XGB】使用决策阈值=0.400（fixed 模式）
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [15:25:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [15:25:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [15:25:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [15:25:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\baselines.py:109: RuntimeWarning: Mean of empty slice
#   summary[f"{col}_mean"] = float(np.nanmean(arr))
# d:\Anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [15:25:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 【INFO】【2026-03-26 15:25:35】【基线-XGB】整体指标：AUC_mean=0.929, AUC_std=0.002, BAC_mean=0.825, BAC_std=0.004, BND_ratio_mean=0.000, BND_ratio_std=0.000, F1_mean=0.730, F1_std=0.005, Kappa_mean=0.643, Kappa_std=0.007, MCC_mean=0.643, MCC_std=0.007, POS_Coverage_mean=nan, POS_Coverage_std=nan, Precision_mean=0.717, Precision_std=0.008, Recall_mean=0.744, Recall_std=0.006, Regret_mean=0.145, Regret_std=0.003
# 【INFO】【2026-03-26 15:25:35】【K折实验】正在执行第 1/5 折...
# 【INFO】【2026-03-26 15:25:35】[BT] 使用桶评分配置：mode=f1_regret_bnd, f1_weight=1.0, regret_weight=1.0, bnd_weight=0.5
# 【INFO】【2026-03-26 15:25:36】【BTTWD】全局模型训练完成，用于兜底预测
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=ROOT，level=0，parent_id=ROOT，split_name=ROOT，split_type=ROOT，split_rule="all"，n_samples=26048
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=mid，level=1，parent_id=ROOT，split_name=L1_age，split_type=numeric_bin，split_rule="mid"，n_samples=6816
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=old，level=1，parent_id=ROOT，split_name=L1_age，split_type=numeric_bin，split_rule="old"，n_samples=8963
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=very_old，level=1，parent_id=ROOT，split_name=L1_age，split_type=numeric_bin，split_rule="very_old"，n_samples=5142
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=young，level=1，parent_id=ROOT，split_name=L1_age，split_type=numeric_bin，split_rule="young"，n_samples=5127
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=mid|L2_education=high，level=2，parent_id=L1_age=mid，split_name=L2_education，split_type=categorical_group，split_rule="high"，n_samples=3406
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=mid|L2_education=low，level=2，parent_id=L1_age=mid，split_name=L2_education，split_type=categorical_group，split_rule="low"，n_samples=166
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=mid|L2_education=mid，level=2，parent_id=L1_age=mid，split_name=L2_education，split_type=categorical_group，split_rule="mid"，n_samples=2809
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=mid|L2_education=top，level=2，parent_id=L1_age=mid，split_name=L2_education，split_type=categorical_group，split_rule="top"，n_samples=435
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=old|L2_education=high，level=2，parent_id=L1_age=old，split_name=L2_education，split_type=categorical_group，split_rule="high"，n_samples=4272
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=old|L2_education=low，level=2，parent_id=L1_age=old，split_name=L2_education，split_type=categorical_group，split_rule="low"，n_samples=270
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=old|L2_education=mid，level=2，parent_id=L1_age=old，split_name=L2_education，split_type=categorical_group，split_rule="mid"，n_samples=3335
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=old|L2_education=top，level=2，parent_id=L1_age=old，split_name=L2_education，split_type=categorical_group，split_rule="top"，n_samples=1086
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=very_old|L2_education=high，level=2，parent_id=L1_age=very_old，split_name=L2_education，split_type=categorical_group，split_rule="high"，n_samples=1870
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=very_old|L2_education=low，level=2，parent_id=L1_age=very_old，split_name=L2_education，split_type=categorical_group，split_rule="low"，n_samples=412
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=very_old|L2_education=mid，level=2，parent_id=L1_age=very_old，split_name=L2_education，split_type=categorical_group，split_rule="mid"，n_samples=2270
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=very_old|L2_education=top，level=2，parent_id=L1_age=very_old，split_name=L2_education，split_type=categorical_group，split_rule="top"，n_samples=590
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=young|L2_education=high，level=2，parent_id=L1_age=young，split_name=L2_education，split_type=categorical_group，split_rule="high"，n_samples=2552
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=young|L2_education=low，level=2，parent_id=L1_age=young，split_name=L2_education，split_type=categorical_group，split_rule="low"，n_samples=119
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=young|L2_education=mid，level=2，parent_id=L1_age=young，split_name=L2_education，split_type=categorical_group，split_rule="mid"，n_samples=2416
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=young|L2_education=others，level=2，parent_id=L1_age=young，split_name=L2_education，split_type=categorical_group，split_rule="others"，n_samples=40
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=mid|L2_education=high|L3_hours-per-week=high_hours，level=3，parent_id=L1_age=mid|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="high_hours"，n_samples=884
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=mid|L2_education=high|L3_hours-per-week=low_hours，level=3，parent_id=L1_age=mid|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="low_hours"，n_samples=426
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=mid|L2_education=high|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=mid|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=2096
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=mid|L2_education=low|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=mid|L2_education=low，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=107
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=mid|L2_education=low|L3_hours-per-week=others，level=3，parent_id=L1_age=mid|L2_education=low，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="others"，n_samples=59
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=mid|L2_education=mid|L3_hours-per-week=high_hours，level=3，parent_id=L1_age=mid|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="high_hours"，n_samples=579
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=mid|L2_education=mid|L3_hours-per-week=low_hours，level=3，parent_id=L1_age=mid|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="low_hours"，n_samples=374
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=mid|L2_education=mid|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=mid|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=1856
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=mid|L2_education=top|L3_hours-per-week=high_hours，level=3，parent_id=L1_age=mid|L2_education=top，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="high_hours"，n_samples=175
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=mid|L2_education=top|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=mid|L2_education=top，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=200
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=mid|L2_education=top|L3_hours-per-week=others，level=3，parent_id=L1_age=mid|L2_education=top，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="others"，n_samples=60
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=old|L2_education=high|L3_hours-per-week=high_hours，level=3，parent_id=L1_age=old|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="high_hours"，n_samples=1248
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=old|L2_education=high|L3_hours-per-week=low_hours，level=3，parent_id=L1_age=old|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="low_hours"，n_samples=438
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=old|L2_education=high|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=old|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=2586
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=old|L2_education=low|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=old|L2_education=low，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=174
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=old|L2_education=low|L3_hours-per-week=others，level=3，parent_id=L1_age=old|L2_education=low，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="others"，n_samples=96
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=old|L2_education=mid|L3_hours-per-week=high_hours，level=3，parent_id=L1_age=old|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="high_hours"，n_samples=727
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=old|L2_education=mid|L3_hours-per-week=low_hours，level=3，parent_id=L1_age=old|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="low_hours"，n_samples=429
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=old|L2_education=mid|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=old|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=2179
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=old|L2_education=top|L3_hours-per-week=high_hours，level=3，parent_id=L1_age=old|L2_education=top，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="high_hours"，n_samples=457
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=old|L2_education=top|L3_hours-per-week=low_hours，level=3，parent_id=L1_age=old|L2_education=top，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="low_hours"，n_samples=103
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=old|L2_education=top|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=old|L2_education=top，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=526
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=very_old|L2_education=high|L3_hours-per-week=high_hours，level=3，parent_id=L1_age=very_old|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="high_hours"，n_samples=442
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=very_old|L2_education=high|L3_hours-per-week=low_hours，level=3，parent_id=L1_age=very_old|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="low_hours"，n_samples=438
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=very_old|L2_education=high|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=very_old|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=990
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=very_old|L2_education=low|L3_hours-per-week=low_hours，level=3，parent_id=L1_age=very_old|L2_education=low，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="low_hours"，n_samples=138
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=very_old|L2_education=low|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=very_old|L2_education=low，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=205
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=very_old|L2_education=low|L3_hours-per-week=others，level=3，parent_id=L1_age=very_old|L2_education=low，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="others"，n_samples=69
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=very_old|L2_education=mid|L3_hours-per-week=high_hours，level=3，parent_id=L1_age=very_old|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="high_hours"，n_samples=360
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=very_old|L2_education=mid|L3_hours-per-week=low_hours，level=3，parent_id=L1_age=very_old|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="low_hours"，n_samples=614
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=very_old|L2_education=mid|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=very_old|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=1296
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=very_old|L2_education=top|L3_hours-per-week=high_hours，level=3，parent_id=L1_age=very_old|L2_education=top，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="high_hours"，n_samples=221
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=very_old|L2_education=top|L3_hours-per-week=low_hours，level=3，parent_id=L1_age=very_old|L2_education=top，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="low_hours"，n_samples=112
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=very_old|L2_education=top|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=very_old|L2_education=top，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=257
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=young|L2_education=high|L3_hours-per-week=high_hours，level=3，parent_id=L1_age=young|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="high_hours"，n_samples=234
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=young|L2_education=high|L3_hours-per-week=low_hours，level=3，parent_id=L1_age=young|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="low_hours"，n_samples=1198
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=young|L2_education=high|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=young|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=1120
# [INFO][BT][2026-03-26 15:25:36] 桶 bucket_id=L1_age=young|L2_education=low 不再细分：3 个子桶样本数不足 min_bucket_size=100
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=young|L2_education=mid|L3_hours-per-week=high_hours，level=3，parent_id=L1_age=young|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="high_hours"，n_samples=221
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=young|L2_education=mid|L3_hours-per-week=low_hours，level=3，parent_id=L1_age=young|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="low_hours"，n_samples=1052
# [INFO][BT][2026-03-26 15:25:36] 创建桶 bucket_id=L1_age=young|L2_education=mid|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=young|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=1143
# [INFO][BT][2026-03-26 15:25:38] 桶树构建完成：总桶数=61，最大层数=3，叶子桶数=42
# 【INFO】【2026-03-26 15:25:38】【BTTWD】bucket_estimator=none：不训练桶内局部模型，仅使用全局模型概率做桶内阈值搜索
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\bucket_gain.py:27: RuntimeWarning: compute_bucket_score: metric 'F1' is missing or NaN, defaulting to 0.0.
#   warnings.warn(
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\bucket_gain.py:27: RuntimeWarning: compute_bucket_score: metric 'BND_ratio' is missing or NaN, defaulting to 0.0.
#   warnings.warn(
# 【INFO】【2026-03-26 15:25:38】【阈值】桶 ROOT（n_val=1561，source=val) 使用本地阈值 α=0.4000, β=0.3000
# [INFO][BT][2026-03-26 15:25:38] 桶 bucket_id=ROOT level=0：
#     n_train=3645, n_val=1561,
#     BAC=0.814, F1=0.723, AUC=0.929,
#     Regret=0.131, BND_ratio=0.047, POS_coverage=0.240,
#     Score(f1_regret_bnd )=0.569，threshold_source=val
# 【INFO】【2026-03-26 15:25:38】【阈值】桶 L1_age=mid 标记为弱桶，阈值将回退使用 ROOT 的阈值
# [INFO][BT][2026-03-26 15:25:38] 桶 bucket_id=L1_age=mid level=1：
#     n_train=953, n_val=448,
#     BAC=0.721, F1=0.612, AUC=0.899,
#     Regret=0.118, BND_ratio=0.109, POS_coverage=0.129,
#     Score(f1_regret_bnd )=0.439，threshold_source=val
# [INFO][BT][2026-03-26 15:25:38] 桶 bucket_id=L1_age=mid：
#     parent_id=ROOT，parent_Score=0.569, bucket_Score=0.439,
#     Gain=-0.131, is_weak=True
# 【INFO】【2026-03-26 15:25:38】【阈值】桶 L1_age=old 标记为弱桶，阈值将回退使用 ROOT 的阈值
# [INFO][BT][2026-03-26 15:25:38] 桶 bucket_id=L1_age=old level=1：
#     n_train=1256, n_val=591,
#     BAC=0.747, F1=0.748, AUC=0.902,
#     Regret=0.176, BND_ratio=0.132, POS_coverage=0.377,
#     Score(f1_regret_bnd )=0.506，threshold_source=val
# [INFO][BT][2026-03-26 15:25:38] 桶 bucket_id=L1_age=old：
#     parent_id=ROOT，parent_Score=0.569, bucket_Score=0.506,
#     Gain=-0.063, is_weak=True
# 【INFO】【2026-03-26 15:25:39】【阈值】桶 L1_age=very_old 标记为弱桶，阈值将回退使用 ROOT 的阈值
# [INFO][BT][2026-03-26 15:25:39] 桶 bucket_id=L1_age=very_old level=1：
#     n_train=717, n_val=308,
#     BAC=0.734, F1=0.720, AUC=0.887,
#     Regret=0.192, BND_ratio=0.120, POS_coverage=0.279,
#     Score(f1_regret_bnd )=0.469，threshold_source=val
# [INFO][BT][2026-03-26 15:25:39] 桶 bucket_id=L1_age=very_old：
#     parent_id=ROOT，parent_Score=0.569, bucket_Score=0.469,
#     Gain=-0.100, is_weak=True
# 【INFO】【2026-03-26 15:25:39】【阈值】桶 L1_age=young（n_val=355，source=val) 使用本地阈值 α=0.5000, β=0.4000
# [INFO][BT][2026-03-26 15:25:39] 桶 bucket_id=L1_age=young level=1：
#     n_train=795, n_val=355,
#     BAC=0.875, F1=0.857, AUC=0.996,
#     Regret=0.004, BND_ratio=0.000, POS_coverage=0.008,
#     Score(f1_regret_bnd )=0.853，threshold_source=val
# [INFO][BT][2026-03-26 15:25:39] 桶 bucket_id=L1_age=young：
#     parent_id=ROOT，parent_Score=0.569, bucket_Score=0.853,
#     Gain=+0.284, is_weak=False
# 【INFO】【2026-03-26 15:25:39】【阈值】桶 L1_age=mid|L2_education=high 标记为弱桶，阈值将回退使用 L1_age=mid 的阈值
# [INFO][BT][2026-03-26 15:25:39] 桶 bucket_id=L1_age=mid|L2_education=high level=2：
#     n_train=482, n_val=196,
#     BAC=0.687, F1=0.667, AUC=0.901,
#     Regret=0.166, BND_ratio=0.173, POS_coverage=0.168,
#     Score(f1_regret_bnd )=0.414，threshold_source=val
# [INFO][BT][2026-03-26 15:25:39] 桶 bucket_id=L1_age=mid|L2_education=high：
#     parent_id=L1_age=mid，parent_Score=0.439, bucket_Score=0.414,
#     Gain=-0.024, is_weak=True
# 【INFO】【2026-03-26 15:25:39】【阈值】桶 L1_age=mid|L2_education=low 标记为弱桶，阈值将回退使用 L1_age=mid 的阈值
# [INFO][BT][2026-03-26 15:25:39] 桶 bucket_id=L1_age=mid|L2_education=low level=2：
#     n_train=116, n_val=50,
#     BAC=0.500, F1=0.000, AUC=0.775,
#     Regret=0.027, BND_ratio=0.000, POS_coverage=0.000,
#     Score(f1_regret_bnd )=nan，threshold_source=all
# [INFO][BT][2026-03-26 15:25:39] 桶 bucket_id=L1_age=mid|L2_education=low：
#     parent_id=L1_age=mid，parent_Score=0.439, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2026-03-26 15:25:40】【阈值】桶 L1_age=mid|L2_education=mid 标记为弱桶，阈值将回退使用 L1_age=mid 的阈值
# [INFO][BT][2026-03-26 15:25:40] 桶 bucket_id=L1_age=mid|L2_education=mid level=2：
#     n_train=384, n_val=175,
#     BAC=0.560, F1=0.320, AUC=0.880,
#     Regret=0.131, BND_ratio=0.103, POS_coverage=0.023,
#     Score(f1_regret_bnd )=0.137，threshold_source=val
# [INFO][BT][2026-03-26 15:25:40] 桶 bucket_id=L1_age=mid|L2_education=mid：
#     parent_id=L1_age=mid，parent_Score=0.439, bucket_Score=0.137,
#     Gain=-0.301, is_weak=True
# 【INFO】【2026-03-26 15:25:40】【阈值】桶 L1_age=mid|L2_education=top（n_val=124，source=val) 使用本地阈值 α=0.6000, β=0.5000
# [INFO][BT][2026-03-26 15:25:40] 桶 bucket_id=L1_age=mid|L2_education=top level=2：
#     n_train=94, n_val=124,
#     BAC=0.777, F1=0.764, AUC=0.910,
#     Regret=0.179, BND_ratio=0.081, POS_coverage=0.379,
#     Score(f1_regret_bnd )=0.544，threshold_source=val
# [INFO][BT][2026-03-26 15:25:40] 桶 bucket_id=L1_age=mid|L2_education=top：
#     parent_id=L1_age=mid，parent_Score=0.439, bucket_Score=0.544,
#     Gain=+0.106, is_weak=False
# 【INFO】【2026-03-26 15:25:40】【阈值】桶 L1_age=old|L2_education=high（n_val=256，source=val) 使用本地阈值 α=0.4000, β=0.2000
# [INFO][BT][2026-03-26 15:25:40] 桶 bucket_id=L1_age=old|L2_education=high level=2：
#     n_train=597, n_val=256,
#     BAC=0.760, F1=0.816, AUC=0.913,
#     Regret=0.156, BND_ratio=0.129, POS_coverage=0.504,
#     Score(f1_regret_bnd )=0.596，threshold_source=val
# [INFO][BT][2026-03-26 15:25:40] 桶 bucket_id=L1_age=old|L2_education=high：
#     parent_id=L1_age=old，parent_Score=0.506, bucket_Score=0.596,
#     Gain=+0.090, is_weak=False
# 【INFO】【2026-03-26 15:25:40】【阈值】桶 L1_age=old|L2_education=low 标记为弱桶，阈值将回退使用 L1_age=old 的阈值
# [INFO][BT][2026-03-26 15:25:40] 桶 bucket_id=L1_age=old|L2_education=low level=2：
#     n_train=95, n_val=71,
#     BAC=0.576, F1=0.250, AUC=0.723,
#     Regret=0.116, BND_ratio=0.000, POS_coverage=0.028,
#     Score(f1_regret_bnd )=0.134，threshold_source=val
# [INFO][BT][2026-03-26 15:25:40] 桶 bucket_id=L1_age=old|L2_education=low：
#     parent_id=L1_age=old，parent_Score=0.506, bucket_Score=0.134,
#     Gain=-0.372, is_weak=True
# 【INFO】【2026-03-26 15:25:40】【阈值】桶 L1_age=old|L2_education=mid 标记为弱桶，阈值将回退使用 L1_age=old 的阈值
# [INFO][BT][2026-03-26 15:25:40] 桶 bucket_id=L1_age=old|L2_education=mid level=2：
#     n_train=468, n_val=197,
#     BAC=0.700, F1=0.600, AUC=0.884,
#     Regret=0.178, BND_ratio=0.107, POS_coverage=0.198,
#     Score(f1_regret_bnd )=0.369，threshold_source=val
# [INFO][BT][2026-03-26 15:25:40] 桶 bucket_id=L1_age=old|L2_education=mid：
#     parent_id=L1_age=old，parent_Score=0.506, bucket_Score=0.369,
#     Gain=-0.137, is_weak=True
# 【INFO】【2026-03-26 15:25:41】【阈值】桶 L1_age=old|L2_education=top（n_val=93，source=val) 使用本地阈值 α=0.4000, β=0.3000
# [INFO][BT][2026-03-26 15:25:41] 桶 bucket_id=L1_age=old|L2_education=top level=2：
#     n_train=204, n_val=93,
#     BAC=0.859, F1=0.939, AUC=0.958,
#     Regret=0.075, BND_ratio=0.011, POS_coverage=0.742,
#     Score(f1_regret_bnd )=0.859，threshold_source=val
# [INFO][BT][2026-03-26 15:25:41] 桶 bucket_id=L1_age=old|L2_education=top：
#     parent_id=L1_age=old，parent_Score=0.506, bucket_Score=0.859,
#     Gain=+0.353, is_weak=False
# 【INFO】【2026-03-26 15:25:41】【阈值】桶 L1_age=very_old|L2_education=high（n_val=108，source=val) 使用本地阈值 α=0.6000, β=0.3000
# [INFO][BT][2026-03-26 15:25:41] 桶 bucket_id=L1_age=very_old|L2_education=high level=2：
#     n_train=264, n_val=108,
#     BAC=0.754, F1=0.830, AUC=0.909,
#     Regret=0.171, BND_ratio=0.148, POS_coverage=0.417,
#     Score(f1_regret_bnd )=0.584，threshold_source=val
# [INFO][BT][2026-03-26 15:25:41] 桶 bucket_id=L1_age=very_old|L2_education=high：
#     parent_id=L1_age=very_old，parent_Score=0.469, bucket_Score=0.584,
#     Gain=+0.116, is_weak=False
# 【INFO】【2026-03-26 15:25:41】【阈值】桶 L1_age=very_old|L2_education=low 标记为弱桶，阈值将回退使用 L1_age=very_old 的阈值
# [INFO][BT][2026-03-26 15:25:41] 桶 bucket_id=L1_age=very_old|L2_education=low level=2：
#     n_train=169, n_val=131,
#     BAC=0.587, F1=0.286, AUC=0.852,
#     Regret=0.103, BND_ratio=0.008, POS_coverage=0.023,
#     Score(f1_regret_bnd )=0.179，threshold_source=val
# [INFO][BT][2026-03-26 15:25:41] 桶 bucket_id=L1_age=very_old|L2_education=low：
#     parent_id=L1_age=very_old，parent_Score=0.469, bucket_Score=0.179,
#     Gain=-0.290, is_weak=True
# 【INFO】【2026-03-26 15:25:41】【阈值】桶 L1_age=very_old|L2_education=mid 标记为弱桶，阈值将回退使用 L1_age=very_old 的阈值
# [INFO][BT][2026-03-26 15:25:41] 桶 bucket_id=L1_age=very_old|L2_education=mid level=2：
#     n_train=314, n_val=138,
#     BAC=0.693, F1=0.640, AUC=0.857,
#     Regret=0.178, BND_ratio=0.109, POS_coverage=0.138,
#     Score(f1_regret_bnd )=0.408，threshold_source=val
# [INFO][BT][2026-03-26 15:25:41] 桶 bucket_id=L1_age=very_old|L2_education=mid：
#     parent_id=L1_age=very_old，parent_Score=0.469, bucket_Score=0.408,
#     Gain=-0.061, is_weak=True
# 【INFO】【2026-03-26 15:25:41】【阈值】桶 L1_age=very_old|L2_education=top（n_val=178，source=val) 使用本地阈值 α=0.7000, β=0.3000
# [INFO][BT][2026-03-26 15:25:41] 桶 bucket_id=L1_age=very_old|L2_education=top level=2：
#     n_train=148, n_val=178,
#     BAC=0.612, F1=0.845, AUC=0.859,
#     Regret=0.204, BND_ratio=0.219, POS_coverage=0.601,
#     Score(f1_regret_bnd )=0.532，threshold_source=val
# [INFO][BT][2026-03-26 15:25:41] 桶 bucket_id=L1_age=very_old|L2_education=top：
#     parent_id=L1_age=very_old，parent_Score=0.469, bucket_Score=0.532,
#     Gain=+0.063, is_weak=False
# 【INFO】【2026-03-26 15:25:42】【阈值】桶 L1_age=young|L2_education=high 标记为弱桶，阈值将回退使用 L1_age=young 的阈值
# [INFO][BT][2026-03-26 15:25:42] 桶 bucket_id=L1_age=young|L2_education=high level=2：
#     n_train=359, n_val=200,
#     BAC=0.790, F1=0.750, AUC=0.993,
#     Regret=0.013, BND_ratio=0.030, POS_coverage=0.015,
#     Score(f1_regret_bnd )=0.722，threshold_source=val
# [INFO][BT][2026-03-26 15:25:42] 桶 bucket_id=L1_age=young|L2_education=high：
#     parent_id=L1_age=young，parent_Score=0.853, bucket_Score=0.722,
#     Gain=-0.130, is_weak=True
# 【INFO】【2026-03-26 15:25:42】【阈值】桶 L1_age=young|L2_education=low 标记为弱桶，阈值将回退使用 L1_age=young 的阈值
# [INFO][BT][2026-03-26 15:25:42] 桶 bucket_id=L1_age=young|L2_education=low level=2：
#     n_train=74, n_val=45,
#     BAC=0.667, F1=0.500, AUC=0.954,
#     Regret=0.025, BND_ratio=0.000, POS_coverage=0.008,
#     Score(f1_regret_bnd )=nan，threshold_source=all
# [INFO][BT][2026-03-26 15:25:42] 桶 bucket_id=L1_age=young|L2_education=low：
#     parent_id=L1_age=young，parent_Score=0.853, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2026-03-26 15:25:42】【阈值】桶 L1_age=young|L2_education=mid 标记为弱桶，阈值将回退使用 L1_age=young 的阈值
# [INFO][BT][2026-03-26 15:25:42] 桶 bucket_id=L1_age=young|L2_education=mid level=2：
#     n_train=336, n_val=199,
#     BAC=0.750, F1=0.667, AUC=0.968,
#     Regret=0.015, BND_ratio=0.000, POS_coverage=0.010,
#     Score(f1_regret_bnd )=0.652，threshold_source=val
# [INFO][BT][2026-03-26 15:25:42] 桶 bucket_id=L1_age=young|L2_education=mid：
#     parent_id=L1_age=young，parent_Score=0.853, bucket_Score=0.652,
#     Gain=-0.201, is_weak=True
# 【INFO】【2026-03-26 15:25:42】【阈值】桶 L1_age=young|L2_education=others 标记为弱桶，阈值将回退使用 L1_age=young 的阈值
# [INFO][BT][2026-03-26 15:25:42] 桶 bucket_id=L1_age=young|L2_education=others level=2：
#     n_train=26, n_val=14,
#     BAC=0.833, F1=0.800, AUC=0.856,
#     Regret=0.037, BND_ratio=0.000, POS_coverage=0.050,
#     Score(f1_regret_bnd )=nan，threshold_source=all
# [INFO][BT][2026-03-26 15:25:42] 桶 bucket_id=L1_age=young|L2_education=others：
#     parent_id=L1_age=young，parent_Score=0.853, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2026-03-26 15:25:42】【阈值】桶 L1_age=mid|L2_education=high|L3_hours-per-week=high_hours（n_val=269，source=val) 使用本地阈值 α=0.4000, β=0.3000
# [INFO][BT][2026-03-26 15:25:42] 桶 bucket_id=L1_age=mid|L2_education=high|L3_hours-per-week=high_hours level=3：
#     n_train=615, n_val=269,
#     BAC=0.726, F1=0.724, AUC=0.874,
#     Regret=0.223, BND_ratio=0.104, POS_coverage=0.353,
#     Score(f1_regret_bnd )=0.449，threshold_source=val
# [INFO][BT][2026-03-26 15:25:42] 桶 bucket_id=L1_age=mid|L2_education=high|L3_hours-per-week=high_hours：
#     parent_id=L1_age=mid|L2_education=high，parent_Score=0.414, bucket_Score=0.449,
#     Gain=+0.035, is_weak=False
# 【INFO】【2026-03-26 15:25:43】【阈值】桶 L1_age=mid|L2_education=high|L3_hours-per-week=low_hours（n_val=122，source=val) 使用本地阈值 α=0.5000, β=0.3000
# [INFO][BT][2026-03-26 15:25:43] 桶 bucket_id=L1_age=mid|L2_education=high|L3_hours-per-week=low_hours level=3：
#     n_train=304, n_val=122,
#     BAC=0.849, F1=0.750, AUC=0.974,
#     Regret=0.039, BND_ratio=0.041, POS_coverage=0.066,
#     Score(f1_regret_bnd )=0.691，threshold_source=val
# [INFO][BT][2026-03-26 15:25:43] 桶 bucket_id=L1_age=mid|L2_education=high|L3_hours-per-week=low_hours：
#     parent_id=L1_age=mid|L2_education=high，parent_Score=0.414, bucket_Score=0.691,
#     Gain=+0.276, is_weak=False
# 【INFO】【2026-03-26 15:25:43】【阈值】桶 L1_age=mid|L2_education=high|L3_hours-per-week=normal_hours 标记为弱桶，阈值将回退使用 L1_age=mid|L2_education=high 的阈值
# [INFO][BT][2026-03-26 15:25:43] 桶 bucket_id=L1_age=mid|L2_education=high|L3_hours-per-week=normal_hours level=3：
#     n_train=1497, n_val=599,
#     BAC=0.708, F1=0.671, AUC=0.896,
#     Regret=0.163, BND_ratio=0.194, POS_coverage=0.257,
#     Score(f1_regret_bnd )=0.412，threshold_source=val
# [INFO][BT][2026-03-26 15:25:43] 桶 bucket_id=L1_age=mid|L2_education=high|L3_hours-per-week=normal_hours：
#     parent_id=L1_age=mid|L2_education=high，parent_Score=0.414, bucket_Score=0.412,
#     Gain=-0.002, is_weak=True
# 【INFO】【2026-03-26 15:25:43】【阈值】桶 L1_age=mid|L2_education=low|L3_hours-per-week=normal_hours 标记为弱桶，阈值将回退使用 L1_age=mid|L2_education=low 的阈值
# [INFO][BT][2026-03-26 15:25:43] 桶 bucket_id=L1_age=mid|L2_education=low|L3_hours-per-week=normal_hours level=3：
#     n_train=79, n_val=28,
#     BAC=0.500, F1=0.000, AUC=0.763,
#     Regret=0.042, BND_ratio=0.000, POS_coverage=0.000,
#     Score(f1_regret_bnd )=nan，threshold_source=all
# [INFO][BT][2026-03-26 15:25:43] 桶 bucket_id=L1_age=mid|L2_education=low|L3_hours-per-week=normal_hours：
#     parent_id=L1_age=mid|L2_education=low，parent_Score=-0.138, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2026-03-26 15:25:43】【阈值】桶 L1_age=mid|L2_education=low|L3_hours-per-week=others 标记为弱桶，阈值将回退使用 L1_age=mid|L2_education=low 的阈值
# [INFO][BT][2026-03-26 15:25:43] 桶 bucket_id=L1_age=mid|L2_education=low|L3_hours-per-week=others level=3：
#     n_train=37, n_val=22,
#     BAC=nan, F1=nan, AUC=nan,
#     Regret=nan, BND_ratio=nan, POS_coverage=nan,
#     Score(f1_regret_bnd )=nan，threshold_source=all
# [INFO][BT][2026-03-26 15:25:43] 桶 bucket_id=L1_age=mid|L2_education=low|L3_hours-per-week=others：
#     parent_id=L1_age=mid|L2_education=low，parent_Score=-0.138, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2026-03-26 15:25:43】【阈值】桶 L1_age=mid|L2_education=mid|L3_hours-per-week=high_hours 标记为弱桶，阈值将回退使用 L1_age=mid|L2_education=mid 的阈值
# [INFO][BT][2026-03-26 15:25:43] 桶 bucket_id=L1_age=mid|L2_education=mid|L3_hours-per-week=high_hours level=3：
#     n_train=396, n_val=183,
#     BAC=0.493, F1=0.409, AUC=0.780,
#     Regret=0.206, BND_ratio=0.301, POS_coverage=0.049,
#     Score(f1_regret_bnd )=0.053，threshold_source=val
# [INFO][BT][2026-03-26 15:25:43] 桶 bucket_id=L1_age=mid|L2_education=mid|L3_hours-per-week=high_hours：
#     parent_id=L1_age=mid|L2_education=mid，parent_Score=0.137, bucket_Score=0.053,
#     Gain=-0.085, is_weak=True
# 【INFO】【2026-03-26 15:25:44】【阈值】桶 L1_age=mid|L2_education=mid|L3_hours-per-week=low_hours（n_val=119，source=val) 使用本地阈值 α=0.6000, β=0.5000
# [INFO][BT][2026-03-26 15:25:44] 桶 bucket_id=L1_age=mid|L2_education=mid|L3_hours-per-week=low_hours level=3：
#     n_train=255, n_val=119,
#     BAC=0.875, F1=0.857, AUC=0.961,
#     Regret=0.013, BND_ratio=0.000, POS_coverage=0.025,
#     Score(f1_regret_bnd )=0.845，threshold_source=val
# [INFO][BT][2026-03-26 15:25:44] 桶 bucket_id=L1_age=mid|L2_education=mid|L3_hours-per-week=low_hours：
#     parent_id=L1_age=mid|L2_education=mid，parent_Score=0.137, bucket_Score=0.845,
#     Gain=+0.707, is_weak=False
# 【INFO】【2026-03-26 15:25:44】【阈值】桶 L1_age=mid|L2_education=mid|L3_hours-per-week=normal_hours（n_val=582，source=val) 使用本地阈值 α=0.6000, β=0.2000
# [INFO][BT][2026-03-26 15:25:44] 桶 bucket_id=L1_age=mid|L2_education=mid|L3_hours-per-week=normal_hours level=3：
#     n_train=1274, n_val=582,
#     BAC=0.570, F1=0.316, AUC=0.897,
#     Regret=0.088, BND_ratio=0.077, POS_coverage=0.017,
#     Score(f1_regret_bnd )=0.190，threshold_source=val
# [INFO][BT][2026-03-26 15:25:44] 桶 bucket_id=L1_age=mid|L2_education=mid|L3_hours-per-week=normal_hours：
#     parent_id=L1_age=mid|L2_education=mid，parent_Score=0.137, bucket_Score=0.190,
#     Gain=+0.052, is_weak=False
# 【INFO】【2026-03-26 15:25:44】【阈值】桶 L1_age=mid|L2_education=top|L3_hours-per-week=high_hours 标记为弱桶，阈值将回退使用 L1_age=mid|L2_education=top 的阈值
# [INFO][BT][2026-03-26 15:25:44] 桶 bucket_id=L1_age=mid|L2_education=top|L3_hours-per-week=high_hours level=3：
#     n_train=123, n_val=52,
#     BAC=0.525, F1=0.708, AUC=0.813,
#     Regret=0.274, BND_ratio=0.327, POS_coverage=0.481,
#     Score(f1_regret_bnd )=0.271，threshold_source=val
# [INFO][BT][2026-03-26 15:25:44] 桶 bucket_id=L1_age=mid|L2_education=top|L3_hours-per-week=high_hours：
#     parent_id=L1_age=mid|L2_education=top，parent_Score=0.544, bucket_Score=0.271,
#     Gain=-0.273, is_weak=True
# 【INFO】【2026-03-26 15:25:44】【阈值】桶 L1_age=mid|L2_education=top|L3_hours-per-week=normal_hours（n_val=53，source=val) 使用本地阈值 α=0.6000, β=0.5000
# [INFO][BT][2026-03-26 15:25:44] 桶 bucket_id=L1_age=mid|L2_education=top|L3_hours-per-week=normal_hours level=3：
#     n_train=147, n_val=53,
#     BAC=0.802, F1=0.811, AUC=0.959,
#     Regret=0.123, BND_ratio=0.132, POS_coverage=0.377,
#     Score(f1_regret_bnd )=0.622，threshold_source=val
# [INFO][BT][2026-03-26 15:25:44] 桶 bucket_id=L1_age=mid|L2_education=top|L3_hours-per-week=normal_hours：
#     parent_id=L1_age=mid|L2_education=top，parent_Score=0.544, bucket_Score=0.622,
#     Gain=+0.078, is_weak=False
# 【INFO】【2026-03-26 15:25:44】【阈值】桶 L1_age=mid|L2_education=top|L3_hours-per-week=others 标记为弱桶，阈值将回退使用 L1_age=mid|L2_education=top 的阈值
# [INFO][BT][2026-03-26 15:25:44] 桶 bucket_id=L1_age=mid|L2_education=top|L3_hours-per-week=others level=3：
#     n_train=41, n_val=19,
#     BAC=0.899, F1=0.900, AUC=0.989,
#     Regret=0.042, BND_ratio=0.033, POS_coverage=0.150,
#     Score(f1_regret_bnd )=nan，threshold_source=all
# [INFO][BT][2026-03-26 15:25:44] 桶 bucket_id=L1_age=mid|L2_education=top|L3_hours-per-week=others：
#     parent_id=L1_age=mid|L2_education=top，parent_Score=0.544, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2026-03-26 15:25:45】【阈值】桶 L1_age=old|L2_education=high|L3_hours-per-week=high_hours 标记为弱桶，阈值将回退使用 L1_age=old|L2_education=high 的阈值
# [INFO][BT][2026-03-26 15:25:45] 桶 bucket_id=L1_age=old|L2_education=high|L3_hours-per-week=high_hours level=3：
#     n_train=873, n_val=375,
#     BAC=0.614, F1=0.822, AUC=0.847,
#     Regret=0.209, BND_ratio=0.131, POS_coverage=0.733,
#     Score(f1_regret_bnd )=0.548，threshold_source=val
# [INFO][BT][2026-03-26 15:25:45] 桶 bucket_id=L1_age=old|L2_education=high|L3_hours-per-week=high_hours：
#     parent_id=L1_age=old|L2_education=high，parent_Score=0.596, bucket_Score=0.548,
#     Gain=-0.048, is_weak=True
# 【INFO】【2026-03-26 15:25:45】【阈值】桶 L1_age=old|L2_education=high|L3_hours-per-week=low_hours（n_val=135，source=val) 使用本地阈值 α=0.3000, β=0.1000
# [INFO][BT][2026-03-26 15:25:45] 桶 bucket_id=L1_age=old|L2_education=high|L3_hours-per-week=low_hours level=3：
#     n_train=303, n_val=135,
#     BAC=0.798, F1=0.805, AUC=0.934,
#     Regret=0.117, BND_ratio=0.163, POS_coverage=0.311,
#     Score(f1_regret_bnd )=0.607，threshold_source=val
# [INFO][BT][2026-03-26 15:25:45] 桶 bucket_id=L1_age=old|L2_education=high|L3_hours-per-week=low_hours：
#     parent_id=L1_age=old|L2_education=high，parent_Score=0.596, bucket_Score=0.607,
#     Gain=+0.011, is_weak=False
# 【INFO】【2026-03-26 15:25:45】【阈值】桶 L1_age=old|L2_education=high|L3_hours-per-week=normal_hours 标记为弱桶，阈值将回退使用 L1_age=old|L2_education=high 的阈值
# [INFO][BT][2026-03-26 15:25:45] 桶 bucket_id=L1_age=old|L2_education=high|L3_hours-per-week=normal_hours level=3：
#     n_train=1816, n_val=770,
#     BAC=0.681, F1=0.741, AUC=0.887,
#     Regret=0.196, BND_ratio=0.214, POS_coverage=0.391,
#     Score(f1_regret_bnd )=0.438，threshold_source=val
# [INFO][BT][2026-03-26 15:25:45] 桶 bucket_id=L1_age=old|L2_education=high|L3_hours-per-week=normal_hours：
#     parent_id=L1_age=old|L2_education=high，parent_Score=0.596, bucket_Score=0.438,
#     Gain=-0.157, is_weak=True
# 【INFO】【2026-03-26 15:25:45】【阈值】桶 L1_age=old|L2_education=low|L3_hours-per-week=normal_hours（n_val=45，source=val) 使用本地阈值 α=0.4000, β=0.2000
# [INFO][BT][2026-03-26 15:25:45] 桶 bucket_id=L1_age=old|L2_education=low|L3_hours-per-week=normal_hours level=3：
#     n_train=129, n_val=45,
#     BAC=0.613, F1=0.333, AUC=0.683,
#     Regret=0.117, BND_ratio=0.000, POS_coverage=0.044,
#     Score(f1_regret_bnd )=0.217，threshold_source=val
# [INFO][BT][2026-03-26 15:25:45] 桶 bucket_id=L1_age=old|L2_education=low|L3_hours-per-week=normal_hours：
#     parent_id=L1_age=old|L2_education=low，parent_Score=0.134, bucket_Score=0.217,
#     Gain=+0.083, is_weak=False
# 【INFO】【2026-03-26 15:25:46】【阈值】桶 L1_age=old|L2_education=low|L3_hours-per-week=others 标记为弱桶，阈值将回退使用 L1_age=old|L2_education=low 的阈值
# [INFO][BT][2026-03-26 15:25:46] 桶 bucket_id=L1_age=old|L2_education=low|L3_hours-per-week=others level=3：
#     n_train=70, n_val=26,
#     BAC=0.703, F1=0.600, AUC=0.942,
#     Regret=0.052, BND_ratio=0.042, POS_coverage=0.031,
#     Score(f1_regret_bnd )=nan，threshold_source=all
# [INFO][BT][2026-03-26 15:25:46] 桶 bucket_id=L1_age=old|L2_education=low|L3_hours-per-week=others：
#     parent_id=L1_age=old|L2_education=low，parent_Score=0.134, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2026-03-26 15:25:46】【阈值】桶 L1_age=old|L2_education=mid|L3_hours-per-week=high_hours 标记为弱桶，阈值将回退使用 L1_age=old|L2_education=mid 的阈值
# [INFO][BT][2026-03-26 15:25:46] 桶 bucket_id=L1_age=old|L2_education=mid|L3_hours-per-week=high_hours level=3：
#     n_train=517, n_val=210,
#     BAC=0.630, F1=0.633, AUC=0.860,
#     Regret=0.196, BND_ratio=0.248, POS_coverage=0.210,
#     Score(f1_regret_bnd )=0.312，threshold_source=val
# [INFO][BT][2026-03-26 15:25:46] 桶 bucket_id=L1_age=old|L2_education=mid|L3_hours-per-week=high_hours：
#     parent_id=L1_age=old|L2_education=mid，parent_Score=0.369, bucket_Score=0.312,
#     Gain=-0.057, is_weak=True
# 【INFO】【2026-03-26 15:25:46】【阈值】桶 L1_age=old|L2_education=mid|L3_hours-per-week=low_hours（n_val=114，source=val) 使用本地阈值 α=0.4000, β=0.3000
# [INFO][BT][2026-03-26 15:25:46] 桶 bucket_id=L1_age=old|L2_education=mid|L3_hours-per-week=low_hours level=3：
#     n_train=315, n_val=114,
#     BAC=0.819, F1=0.800, AUC=0.983,
#     Regret=0.033, BND_ratio=0.026, POS_coverage=0.035,
#     Score(f1_regret_bnd )=0.754，threshold_source=val
# [INFO][BT][2026-03-26 15:25:46] 桶 bucket_id=L1_age=old|L2_education=mid|L3_hours-per-week=low_hours：
#     parent_id=L1_age=old|L2_education=mid，parent_Score=0.369, bucket_Score=0.754,
#     Gain=+0.385, is_weak=False
# 【INFO】【2026-03-26 15:25:46】【阈值】桶 L1_age=old|L2_education=mid|L3_hours-per-week=normal_hours 标记为弱桶，阈值将回退使用 L1_age=old|L2_education=mid 的阈值
# [INFO][BT][2026-03-26 15:25:46] 桶 bucket_id=L1_age=old|L2_education=mid|L3_hours-per-week=normal_hours level=3：
#     n_train=1512, n_val=667,
#     BAC=0.596, F1=0.577, AUC=0.874,
#     Regret=0.185, BND_ratio=0.273, POS_coverage=0.154,
#     Score(f1_regret_bnd )=0.255，threshold_source=val
# [INFO][BT][2026-03-26 15:25:46] 桶 bucket_id=L1_age=old|L2_education=mid|L3_hours-per-week=normal_hours：
#     parent_id=L1_age=old|L2_education=mid，parent_Score=0.369, bucket_Score=0.255,
#     Gain=-0.114, is_weak=True
# 【INFO】【2026-03-26 15:25:46】【阈值】桶 L1_age=old|L2_education=top|L3_hours-per-week=high_hours（n_val=138，source=val) 使用本地阈值 α=0.4000, β=0.3000
# [INFO][BT][2026-03-26 15:25:46] 桶 bucket_id=L1_age=old|L2_education=top|L3_hours-per-week=high_hours level=3：
#     n_train=319, n_val=138,
#     BAC=0.691, F1=0.946, AUC=0.880,
#     Regret=0.074, BND_ratio=0.022, POS_coverage=0.913,
#     Score(f1_regret_bnd )=0.861，threshold_source=val
# [INFO][BT][2026-03-26 15:25:46] 桶 bucket_id=L1_age=old|L2_education=top|L3_hours-per-week=high_hours：
#     parent_id=L1_age=old|L2_education=top，parent_Score=0.859, bucket_Score=0.861,
#     Gain=+0.002, is_weak=False
# 【INFO】【2026-03-26 15:25:47】【阈值】桶 L1_age=old|L2_education=top|L3_hours-per-week=low_hours 标记为弱桶，阈值将回退使用 L1_age=old|L2_education=top 的阈值
# [INFO][BT][2026-03-26 15:25:47] 桶 bucket_id=L1_age=old|L2_education=top|L3_hours-per-week=low_hours level=3：
#     n_train=68, n_val=35,
#     BAC=0.823, F1=0.913, AUC=0.913,
#     Regret=0.093, BND_ratio=0.057, POS_coverage=0.686,
#     Score(f1_regret_bnd )=0.792，threshold_source=val
# [INFO][BT][2026-03-26 15:25:47] 桶 bucket_id=L1_age=old|L2_education=top|L3_hours-per-week=low_hours：
#     parent_id=L1_age=old|L2_education=top，parent_Score=0.859, bucket_Score=0.792,
#     Gain=-0.067, is_weak=True
# 【INFO】【2026-03-26 15:25:47】【阈值】桶 L1_age=old|L2_education=top|L3_hours-per-week=normal_hours 标记为弱桶，阈值将回退使用 L1_age=old|L2_education=top 的阈值
# [INFO][BT][2026-03-26 15:25:47] 桶 bucket_id=L1_age=old|L2_education=top|L3_hours-per-week=normal_hours level=3：
#     n_train=368, n_val=158,
#     BAC=0.726, F1=0.876, AUC=0.911,
#     Regret=0.155, BND_ratio=0.152, POS_coverage=0.601,
#     Score(f1_regret_bnd )=0.645，threshold_source=val
# [INFO][BT][2026-03-26 15:25:47] 桶 bucket_id=L1_age=old|L2_education=top|L3_hours-per-week=normal_hours：
#     parent_id=L1_age=old|L2_education=top，parent_Score=0.859, bucket_Score=0.645,
#     Gain=-0.213, is_weak=True
# 【INFO】【2026-03-26 15:25:47】【阈值】桶 L1_age=very_old|L2_education=high|L3_hours-per-week=high_hours 标记为弱桶，阈值将回退使用 L1_age=very_old|L2_education=high 的阈值
# [INFO][BT][2026-03-26 15:25:47] 桶 bucket_id=L1_age=very_old|L2_education=high|L3_hours-per-week=high_hours level=3：
#     n_train=306, n_val=136,
#     BAC=0.650, F1=0.762, AUC=0.805,
#     Regret=0.274, BND_ratio=0.051, POS_coverage=0.691,
#     Score(f1_regret_bnd )=0.462，threshold_source=val
# [INFO][BT][2026-03-26 15:25:47] 桶 bucket_id=L1_age=very_old|L2_education=high|L3_hours-per-week=high_hours：
#     parent_id=L1_age=very_old|L2_education=high，parent_Score=0.584, bucket_Score=0.462,
#     Gain=-0.122, is_weak=True
# 【INFO】【2026-03-26 15:25:47】【阈值】桶 L1_age=very_old|L2_education=high|L3_hours-per-week=low_hours 标记为弱桶，阈值将回退使用 L1_age=very_old|L2_education=high 的阈值
# [INFO][BT][2026-03-26 15:25:47] 桶 bucket_id=L1_age=very_old|L2_education=high|L3_hours-per-week=low_hours level=3：
#     n_train=307, n_val=131,
#     BAC=0.739, F1=0.638, AUC=0.797,
#     Regret=0.170, BND_ratio=0.023, POS_coverage=0.145,
#     Score(f1_regret_bnd )=0.457，threshold_source=val
# [INFO][BT][2026-03-26 15:25:47] 桶 bucket_id=L1_age=very_old|L2_education=high|L3_hours-per-week=low_hours：
#     parent_id=L1_age=very_old|L2_education=high，parent_Score=0.584, bucket_Score=0.457,
#     Gain=-0.127, is_weak=True
# 【INFO】【2026-03-26 15:25:48】【阈值】桶 L1_age=very_old|L2_education=high|L3_hours-per-week=normal_hours（n_val=276，source=val) 使用本地阈值 α=0.4000, β=0.3000
# [INFO][BT][2026-03-26 15:25:48] 桶 bucket_id=L1_age=very_old|L2_education=high|L3_hours-per-week=normal_hours level=3：
#     n_train=714, n_val=276,
#     BAC=0.773, F1=0.801, AUC=0.892,
#     Regret=0.184, BND_ratio=0.054, POS_coverage=0.554,
#     Score(f1_regret_bnd )=0.590，threshold_source=val
# [INFO][BT][2026-03-26 15:25:48] 桶 bucket_id=L1_age=very_old|L2_education=high|L3_hours-per-week=normal_hours：
#     parent_id=L1_age=very_old|L2_education=high，parent_Score=0.584, bucket_Score=0.590,
#     Gain=+0.006, is_weak=False
# 【INFO】【2026-03-26 15:25:48】【阈值】桶 L1_age=very_old|L2_education=low|L3_hours-per-week=low_hours 标记为弱桶，阈值将回退使用 L1_age=very_old|L2_education=low 的阈值
# [INFO][BT][2026-03-26 15:25:48] 桶 bucket_id=L1_age=very_old|L2_education=low|L3_hours-per-week=low_hours level=3：
#     n_train=94, n_val=44,
#     BAC=0.500, F1=0.000, AUC=0.977,
#     Regret=0.034, BND_ratio=0.000, POS_coverage=0.000,
#     Score(f1_regret_bnd )=-0.034，threshold_source=val
# [INFO][BT][2026-03-26 15:25:48] 桶 bucket_id=L1_age=very_old|L2_education=low|L3_hours-per-week=low_hours：
#     parent_id=L1_age=very_old|L2_education=low，parent_Score=0.179, bucket_Score=-0.034,
#     Gain=-0.213, is_weak=True
# 【INFO】【2026-03-26 15:25:48】【阈值】桶 L1_age=very_old|L2_education=low|L3_hours-per-week=normal_hours（n_val=66，source=val) 使用本地阈值 α=0.4000, β=0.2000
# [INFO][BT][2026-03-26 15:25:48] 桶 bucket_id=L1_age=very_old|L2_education=low|L3_hours-per-week=normal_hours level=3：
#     n_train=139, n_val=66,
#     BAC=0.616, F1=0.364, AUC=0.812,
#     Regret=0.148, BND_ratio=0.000, POS_coverage=0.045,
#     Score(f1_regret_bnd )=0.216，threshold_source=val
# [INFO][BT][2026-03-26 15:25:48] 桶 bucket_id=L1_age=very_old|L2_education=low|L3_hours-per-week=normal_hours：
#     parent_id=L1_age=very_old|L2_education=low，parent_Score=0.179, bucket_Score=0.216,
#     Gain=+0.037, is_weak=False
# 【INFO】【2026-03-26 15:25:48】【阈值】桶 L1_age=very_old|L2_education=low|L3_hours-per-week=others 标记为弱桶，阈值将回退使用 L1_age=very_old|L2_education=low 的阈值
# [INFO][BT][2026-03-26 15:25:48] 桶 bucket_id=L1_age=very_old|L2_education=low|L3_hours-per-week=others level=3：
#     n_train=48, n_val=21,
#     BAC=0.639, F1=0.500, AUC=0.882,
#     Regret=0.145, BND_ratio=0.101, POS_coverage=0.072,
#     Score(f1_regret_bnd )=nan，threshold_source=all
# [INFO][BT][2026-03-26 15:25:48] 桶 bucket_id=L1_age=very_old|L2_education=low|L3_hours-per-week=others：
#     parent_id=L1_age=very_old|L2_education=low，parent_Score=0.179, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# ...
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=old|L2_education=high|L3_hours-per-week=low_hours: BAC=0.7753, Regret=0.2024, Precision=0.6875, Recall=0.6875
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=old|L2_education=mid|L3_hours-per-week=low_hours: BAC=0.6380, Regret=0.0563, Precision=0.6667, Recall=0.2857
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=young|L2_education=mid|L3_hours-per-week=low_hours: BAC=1.0000, Regret=0.0000, Precision=0.0000, Recall=0.0000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=old|L2_education=mid|L3_hours-per-week=high_hours: BAC=0.7097, Regret=0.2549, Precision=0.6066, Recall=0.5873
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=old|L2_education=top|L3_hours-per-week=high_hours: BAC=0.6660, Regret=0.1055, Precision=0.8990, Recall=0.9570
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=very_old|L2_education=mid|L3_hours-per-week=normal_hours: BAC=0.7381, Regret=0.1955, Precision=0.5857, Recall=0.5857
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=very_old|L2_education=high|L3_hours-per-week=normal_hours: BAC=0.7976, Regret=0.1940, Precision=0.7075, Recall=0.9286
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=old|L2_education=mid|L3_hours-per-week=normal_hours: BAC=0.7158, Regret=0.1816, Precision=0.6471, Recall=0.5000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=mid|L2_education=high|L3_hours-per-week=normal_hours: BAC=0.7563, Regret=0.1487, Precision=0.6404, Recall=0.5876
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=old|L2_education=high|L3_hours-per-week=normal_hours: BAC=0.7953, Regret=0.1912, Precision=0.7055, Recall=0.8352
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=young|L2_education=high|L3_hours-per-week=high_hours: BAC=0.6250, Regret=0.1214, Precision=1.0000, Recall=0.2500
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=old|L2_education=high|L3_hours-per-week=high_hours: BAC=0.7431, Regret=0.2239, Precision=0.7217, Recall=0.9107
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=young|L2_education=high|L3_hours-per-week=normal_hours: BAC=0.4967, Regret=0.0227, Precision=0.0000, Recall=0.0000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=very_old|L2_education=mid|L3_hours-per-week=high_hours: BAC=0.6385, Regret=0.3795, Precision=0.6429, Recall=0.6429
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=mid|L2_education=mid|L3_hours-per-week=normal_hours: BAC=0.5978, Regret=0.1243, Precision=0.5000, Recall=0.2174
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=very_old|L2_education=high|L3_hours-per-week=low_hours: BAC=0.8503, Regret=0.1387, Precision=0.7083, Recall=0.7727
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=old|L2_education=top|L3_hours-per-week=normal_hours: BAC=0.7714, Regret=0.1587, Precision=0.7857, Recall=0.9429
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=mid|L2_education=top|L3_hours-per-week=normal_hours: BAC=0.7958, Regret=0.1684, Precision=0.7917, Recall=0.7917
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=young|L2_education=mid|L3_hours-per-week=normal_hours: BAC=0.6250, Regret=0.0178, Precision=1.0000, Recall=0.2500
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=very_old|L2_education=low|L3_hours-per-week=normal_hours: BAC=0.7500, Regret=0.0463, Precision=1.0000, Recall=0.5000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=very_old|L2_education=mid|L3_hours-per-week=low_hours: BAC=0.4934, Regret=0.0865, Precision=0.0000, Recall=0.0000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=young|L2_education=high|L3_hours-per-week=low_hours: BAC=0.5000, Regret=0.0103, Precision=0.0000, Recall=0.0000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=very_old|L2_education=top|L3_hours-per-week=normal_hours: BAC=0.7556, Regret=0.1769, Precision=0.8367, Recall=0.9111
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=young|L2_education=low|L3_hours-per-week=normal_hours: BAC=1.0000, Regret=0.0000, Precision=0.0000, Recall=0.0000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=very_old|L2_education=top|L3_hours-per-week=low_hours: BAC=0.8167, Regret=0.1852, Precision=0.7692, Recall=0.8333
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=mid|L2_education=mid|L3_hours-per-week=low_hours: BAC=0.6194, Regret=0.0426, Precision=0.5000, Recall=0.2500
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=mid|L2_education=high|L3_hours-per-week=low_hours: BAC=0.7817, Regret=0.0928, Precision=0.7500, Recall=0.6000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=very_old|L2_education=low|L3_hours-per-week=low_hours: BAC=0.5000, Regret=0.0429, Precision=0.0000, Recall=0.0000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=very_old|L2_education=top|L3_hours-per-week=high_hours: BAC=0.6538, Regret=0.1806, Precision=0.7917, Recall=0.9744
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=very_old|L2_education=high|L3_hours-per-week=high_hours: BAC=0.7532, Regret=0.2109, Precision=0.7534, Recall=0.8594
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=old|L2_education=low|L3_hours-per-week=low_hours: BAC=0.5000, Regret=0.1250, Precision=0.0000, Recall=0.0000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=mid|L2_education=mid|L3_hours-per-week=high_hours: BAC=0.6974, Regret=0.1747, Precision=0.5556, Recall=0.4545
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=old|L2_education=top|L3_hours-per-week=low_hours: BAC=0.8167, Regret=0.2200, Precision=0.9167, Recall=0.7333
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=very_old|L2_education=low|L3_hours-per-week=high_hours: BAC=0.9167, Regret=0.1250, Precision=0.5000, Recall=1.0000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=old|L2_education=low|L3_hours-per-week=normal_hours: BAC=0.5000, Regret=0.0449, Precision=0.0000, Recall=0.0000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=mid|L2_education=high|L3_hours-per-week=high_hours: BAC=0.7384, Regret=0.2412, Precision=0.6711, Recall=0.6800
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=mid|L2_education=low|L3_hours-per-week=normal_hours: BAC=1.0000, Regret=0.0083, Precision=0.0000, Recall=0.0000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=young|L2_education=mid|L3_hours-per-week=high_hours: BAC=0.4886, Regret=0.1011, Precision=0.0000, Recall=0.0000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=mid|L2_education=top|L3_hours-per-week=low_hours: BAC=0.7500, Regret=0.0769, Precision=1.0000, Recall=0.5000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=mid|L2_education=top|L3_hours-per-week=high_hours: BAC=0.7357, Regret=0.2500, Precision=0.7500, Recall=0.9000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=old|L2_education=low|L3_hours-per-week=high_hours: BAC=0.5000, Regret=0.2812, Precision=0.0000, Recall=0.0000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=mid|L2_education=low|L3_hours-per-week=low_hours: BAC=1.0000, Regret=0.0000, Precision=0.0000, Recall=0.0000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=young|L2_education=top|L3_hours-per-week=normal_hours: BAC=1.0000, Regret=0.0000, Precision=0.0000, Recall=0.0000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=young|L2_education=low|L3_hours-per-week=high_hours: BAC=0.5000, Regret=0.1875, Precision=0.0000, Recall=0.0000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=young|L2_education=low|L3_hours-per-week=low_hours: BAC=1.0000, Regret=0.0000, Precision=0.0000, Recall=0.0000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=mid|L2_education=low|L3_hours-per-week=high_hours: BAC=1.0000, Regret=0.0000, Precision=0.0000, Recall=0.0000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=young|L2_education=top|L3_hours-per-week=high_hours: BAC=1.0000, Regret=0.0000, Precision=0.0000, Recall=0.0000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=young|L2_education=top|L3_hours-per-week=low_hours: BAC=1.0000, Regret=0.0000, Precision=0.0000, Recall=0.0000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=old|L2_education=high: BAC=0.7893, Regret=0.2019, Precision=0.7107, Recall=0.8525
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=old: BAC=0.8093, Regret=0.1849, Precision=0.7280, Recall=0.7934
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=old|L2_education=mid: BAC=0.7210, Regret=0.1829, Precision=0.6309, Recall=0.5222
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=young|L2_education=mid: BAC=0.5705, Regret=0.0164, Precision=0.5000, Recall=0.1429
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=young: BAC=0.5702, Regret=0.0229, Precision=0.5000, Recall=0.1429
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=old|L2_education=top: BAC=0.7621, Regret=0.1416, Precision=0.8513, Recall=0.9326
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=very_old|L2_education=mid: BAC=0.7330, Regret=0.1919, Precision=0.5965, Recall=0.5667
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=very_old: BAC=0.8233, Regret=0.1770, Precision=0.7104, Recall=0.8019
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=very_old|L2_education=high: BAC=0.8217, Regret=0.1842, Precision=0.7213, Recall=0.8889
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=mid|L2_education=high: BAC=0.7653, Regret=0.1644, Precision=0.6610, Recall=0.6257
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=mid: BAC=0.7566, Regret=0.1436, Precision=0.6617, Recall=0.5770
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=young|L2_education=high: BAC=0.5754, Regret=0.0277, Precision=0.5000, Recall=0.1538
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=mid|L2_education=mid: BAC=0.6319, Regret=0.1245, Precision=0.5250, Recall=0.2917
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=mid|L2_education=top: BAC=0.8030, Regret=0.1849, Precision=0.7755, Recall=0.8261
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=very_old|L2_education=low: BAC=0.7898, Regret=0.0558, Precision=0.6000, Recall=0.6000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=very_old|L2_education=top: BAC=0.7535, Regret=0.1798, Precision=0.8091, Recall=0.9271
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=young|L2_education=low: BAC=0.5000, Regret=0.0405, Precision=0.0000, Recall=0.0000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=old|L2_education=low: BAC=0.5000, Regret=0.0932, Precision=0.0000, Recall=0.0000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=mid|L2_education=low: BAC=1.0000, Regret=0.0052, Precision=0.0000, Recall=0.0000
# 【INFO】【2026-03-26 15:27:13】[BASELINE] 桶 L1_age=young|L2_education=top: BAC=1.0000, Regret=0.0000, Precision=0.0000, Recall=0.0000
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# d:\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:697: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# 【INFO】【2026-03-26 15:27:13】【K折实验】所有结果已写入 results 目录
#           model  Precision_mean  Precision_std  Recall_mean  Recall_std  \
# 0         BTTWD        0.668038       0.005068     0.797093    0.006025
# 1        LogReg        0.679284       0.008348     0.694556    0.006725
# 2  RandomForest        0.676177       0.006853     0.716619    0.011458
# 3           KNN        0.630564       0.011008     0.686903    0.014062
# 4       XGBoost        0.716983       0.007632     0.744166    0.006066
#
#     F1_mean    F1_std  BAC_mean   BAC_std  AUC_mean  ...  MCC_mean   MCC_std  \
# 0  0.726873  0.004709  0.835723  0.003455  0.927143  ...  0.634440  0.006450
# 1  0.686771  0.003809  0.795235  0.002476  0.906752  ...  0.586058  0.005472
# 2  0.695783  0.008100  0.803880  0.006046  0.905703  ...  0.596043  0.010509
# 3  0.657493  0.011481  0.779616  0.008167  0.868945  ...  0.543573  0.015257
# 4  0.730296  0.005429  0.825481  0.003503  0.929265  ...  0.642849  0.007367
#
#    Kappa_mean  Kappa_std  BND_ratio_mean  BND_ratio_std  POS_Coverage_mean  \
# 0    0.629897   0.006443        0.092657        0.01022           0.239489
# 1    0.585947   0.005562        0.000000        0.00000                NaN
# 2    0.595576   0.010402        0.000000        0.00000                NaN
# 3    0.542658   0.015174        0.000000        0.00000                NaN
# 4    0.642634   0.007398        0.000000        0.00000                NaN
#
#    POS_Coverage_std  Regret_mean  Regret_std
# 0          0.010299     0.143845    0.002028
# 1               NaN     0.169597    0.002065
# 2               NaN     0.164345    0.004596
# 3               NaN     0.185790    0.006517
# 4               NaN     0.145481    0.002938
#
# [5 rows x 21 columns]
# 【INFO】【2026-03-26 15:27:14】【步骤6摘要】BTTWD 与基线的 k 折结果已生成并保存。

# %%
# 步骤7：桶级别分析
bucket_metrics_path = os.path.join(root_path, cfg['OUTPUT']['results_dir'], 'bucket_metrics.csv')
if os.path.exists(bucket_metrics_path):
    bucket_metrics_df = pd.read_csv(bucket_metrics_path)
    display(bucket_metrics_df.head())
    bucket_metrics_df.plot(x='bucket_id', y='pos_rate_all', kind='bar', figsize=(12,4), title='桶正类比例')
    plt.ylabel('正类比例')
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.savefig(fig_bucket, bbox_inches='tight')
    plt.close()
log_info('【步骤7摘要】桶级指标已整理，可用于局部化分析。')
# Out:
#          bucket_id layer parent_bucket_id  n_train  n_val  pos_rate_train  \
# 0             ROOT    L1              NaN     3645   1561        0.238409
# 1       L1_age=old    L1             ROOT     1256    591        0.352707
# 2       L1_age=mid    L1             ROOT      953    448        0.197272
# 3  L1_age=very_old    L1             ROOT      717    308        0.338912
# 4     L1_age=young    L1             ROOT      795    355        0.022642
#
#    pos_rate_val  alpha  beta  regret_val  ...  use_gain_weak_backoff  \
# 0      0.213325    0.4   0.3    0.130685  ...                   True
# 1      0.333333    0.4   0.3    0.175973  ...                   True
# 2      0.140625    0.4   0.3    0.118304  ...                   True
# 3      0.324675    0.4   0.3    0.191558  ...                   True
# 4      0.011268    0.5   0.4    0.004225  ...                   True
#
#    threshold_data_source  parent_with_threshold  n_test  pos_rate_test  \
# 0                    val                    NaN     NaN            NaN
# 1                    val                    NaN     NaN            NaN
# 2                    val                    NaN     NaN            NaN
# 3                    val                    NaN     NaN            NaN
# 4                    val                    NaN     NaN            NaN
#
#    BND_ratio_test  POS_Coverage_test  regret_test  fold  pos_rate
# 0             NaN                NaN          NaN     1  0.240786
# 1             NaN                NaN          NaN     1  0.361486
# 2             NaN                NaN          NaN     1  0.186033
# 3             NaN                NaN          NaN     1  0.325554
# 4             NaN                NaN          NaN     1  0.017554
#
# [5 rows x 38 columns]
# C:\Users\xzq20.HUANLI\AppData\Local\Temp\ipykernel_20392\946468196.py:9: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 【INFO】【2026-03-26 15:27:17】【步骤7摘要】桶级指标已整理，可用于局部化分析。

# %%
# 步骤8：结果汇总
log_info('【步骤8】检查结果文件与图表。')
print(os.listdir(os.path.join(root_path, cfg['OUTPUT']['results_dir'])))
print(os.listdir(os.path.join(root_path, cfg['OUTPUT']['figs_dir'])))
log_info('【全部步骤完成】Adult 数据集上的 BT-TWD 可行性实验结束。')
# Out:
# 【INFO】【2026-03-26 15:27:17】【步骤8】检查结果文件与图表。
# ['analysis_results', 'baseline_bucket_metrics.csv', 'bucket_fallback_stats.csv', 'bucket_metrics.csv', 'bucket_metrics_gain.csv', 'bucket_metrics_gain_test_per_fold.csv', 'bucket_thresholds.csv', 'bucket_thresholds_per_fold.csv', 'bucket_tree_structure.csv', 'fallback_off_tsne', 'fallback_on_tsne', 'metrics_kfold_per_fold.csv', 'metrics_kfold_summary.csv', 'metrics_overview.csv', 'per_sample_test_predictions.csv', 'tsne_fallback']
# ['bank_class_distribution.png', 'bucket_metrics_bar.png', 'class_distribution.png', 'metrics_compare.png']
# 【INFO】【2026-03-26 15:27:17】【全部步骤完成】Adult 数据集上的 BT-TWD 可行性实验结束。

# %%
# 步骤9：t-SNE 可视化弱桶对比
from bttwdlib import visualize_fallback_with_tsne
from IPython.display import Image

# 调用 t-SNE 可视化函数，参数从 YAML 配置中读取
tsne_output_dir = os.path.join(root_path, cfg["OUTPUT"]["results_dir"], "tsne_fallback")
os.makedirs(tsne_output_dir, exist_ok=True)
results = visualize_fallback_with_tsne(config_path=cfg_path, output_dir=tsne_output_dir)

# 显示保存的图片
Image(filename=results["figure_path"])

# 输出其他结果路径
print(f"t-SNE 嵌入结果保存路径：{results['embedding_path']}")
print(f"弱桶对比摘要保存路径：{results['summary_path']}")
print(f"可视化图片保存路径：{results['figure_path']}")
# Out:
# 【INFO】【2026-03-26 15:27:17】【配置加载】已读取 e:\yan\组\三支决策\机器学习\BT_TWD\configs\adult_bttwd.yaml
# 【INFO】【2026-03-26 15:27:17】【数据加载完毕】样本数=32561，特征数=14，正类比例=0.24
# 【INFO】【2026-03-26 15:27:17】【数据加载】24720 条标签无法映射，未指定负类且未开启 dropna_target，已按 0 处理
# 【INFO】【2026-03-26 15:27:17】【数据加载】标签列 income 已处理完成：dropna_target=False, 丢弃样本=0, 最终样本数=32561, 正类比例=24.08%
# 【INFO】【2026-03-26 15:27:17】【数据集信息】名称=adult，样本数=32561，目标列=income，正类比例=24.08%
# 【INFO】【2026-03-26 15:27:17】【预处理】连续特征=6个，类别特征=8个
# 【INFO】【2026-03-26 15:27:17】【预处理】编码后维度=100
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 32561 samples in 0.007s...
# [t-SNE] Computed neighbors for 32561 samples in 2.203s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 32561
# [t-SNE] Computed conditional probabilities for sample 2000 / 32561
# [t-SNE] Computed conditional probabilities for sample 3000 / 32561
# [t-SNE] Computed conditional probabilities for sample 4000 / 32561
# [t-SNE] Computed conditional probabilities for sample 5000 / 32561
# [t-SNE] Computed conditional probabilities for sample 6000 / 32561
# [t-SNE] Computed conditional probabilities for sample 7000 / 32561
# [t-SNE] Computed conditional probabilities for sample 8000 / 32561
# [t-SNE] Computed conditional probabilities for sample 9000 / 32561
# [t-SNE] Computed conditional probabilities for sample 10000 / 32561
# [t-SNE] Computed conditional probabilities for sample 11000 / 32561
# [t-SNE] Computed conditional probabilities for sample 12000 / 32561
# [t-SNE] Computed conditional probabilities for sample 13000 / 32561
# [t-SNE] Computed conditional probabilities for sample 14000 / 32561
# [t-SNE] Computed conditional probabilities for sample 15000 / 32561
# [t-SNE] Computed conditional probabilities for sample 16000 / 32561
# [t-SNE] Computed conditional probabilities for sample 17000 / 32561
# [t-SNE] Computed conditional probabilities for sample 18000 / 32561
# [t-SNE] Computed conditional probabilities for sample 19000 / 32561
# [t-SNE] Computed conditional probabilities for sample 20000 / 32561
# [t-SNE] Computed conditional probabilities for sample 21000 / 32561
# [t-SNE] Computed conditional probabilities for sample 22000 / 32561
# [t-SNE] Computed conditional probabilities for sample 23000 / 32561
# [t-SNE] Computed conditional probabilities for sample 24000 / 32561
# [t-SNE] Computed conditional probabilities for sample 25000 / 32561
# [t-SNE] Computed conditional probabilities for sample 26000 / 32561
# [t-SNE] Computed conditional probabilities for sample 27000 / 32561
# [t-SNE] Computed conditional probabilities for sample 28000 / 32561
# [t-SNE] Computed conditional probabilities for sample 29000 / 32561
# [t-SNE] Computed conditional probabilities for sample 30000 / 32561
# [t-SNE] Computed conditional probabilities for sample 31000 / 32561
# [t-SNE] Computed conditional probabilities for sample 32000 / 32561
# [t-SNE] Computed conditional probabilities for sample 32561 / 32561
# [t-SNE] Mean sigma: 0.692768
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 93.655334
# [t-SNE] KL divergence after 1000 iterations: 2.069810
# 【INFO】【2026-03-26 15:29:18】[t-SNE] Finished embedding computation; adjusted perplexity=40.00, output shape=(32561, 2)
# 【INFO】【2026-03-26 15:29:18】[BT] 使用桶评分配置：mode=f1_regret_bnd, f1_weight=1.0, regret_weight=1.0, bnd_weight=0.5
# C:\Users\xzq20.HUANLI\AppData\Roaming\Python\Python311\site-packages\xgboost\core.py:158: UserWarning: [15:29:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 【INFO】【2026-03-26 15:29:19】【BTTWD】全局模型训练完成，用于兜底预测
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=ROOT，level=0，parent_id=ROOT，split_name=ROOT，split_type=ROOT，split_rule="all"，n_samples=32561
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=mid，level=1，parent_id=ROOT，split_name=L1_age，split_type=numeric_bin，split_rule="mid"，n_samples=8514
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=old，level=1，parent_id=ROOT，split_name=L1_age，split_type=numeric_bin，split_rule="old"，n_samples=11176
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=very_old，level=1，parent_id=ROOT，split_name=L1_age，split_type=numeric_bin，split_rule="very_old"，n_samples=6460
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=young，level=1，parent_id=ROOT，split_name=L1_age，split_type=numeric_bin，split_rule="young"，n_samples=6411
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=mid|L2_education=high，level=2，parent_id=L1_age=mid，split_name=L2_education，split_type=categorical_group，split_rule="high"，n_samples=4218
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=mid|L2_education=low，level=2，parent_id=L1_age=mid，split_name=L2_education，split_type=categorical_group，split_rule="low"，n_samples=213
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=mid|L2_education=mid，level=2，parent_id=L1_age=mid，split_name=L2_education，split_type=categorical_group，split_rule="mid"，n_samples=3530
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=mid|L2_education=top，level=2，parent_id=L1_age=mid，split_name=L2_education，split_type=categorical_group，split_rule="top"，n_samples=553
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=old|L2_education=high，level=2，parent_id=L1_age=old，split_name=L2_education，split_type=categorical_group，split_rule="high"，n_samples=5328
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=old|L2_education=low，level=2，parent_id=L1_age=old，split_name=L2_education，split_type=categorical_group，split_rule="low"，n_samples=328
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=old|L2_education=mid，level=2，parent_id=L1_age=old，split_name=L2_education，split_type=categorical_group，split_rule="mid"，n_samples=4166
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=old|L2_education=top，level=2，parent_id=L1_age=old，split_name=L2_education，split_type=categorical_group，split_rule="top"，n_samples=1354
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=very_old|L2_education=high，level=2，parent_id=L1_age=very_old，split_name=L2_education，split_type=categorical_group，split_rule="high"，n_samples=2333
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=very_old|L2_education=low，level=2，parent_id=L1_age=very_old，split_name=L2_education，split_type=categorical_group，split_rule="low"，n_samples=511
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=very_old|L2_education=mid，level=2，parent_id=L1_age=very_old，split_name=L2_education，split_type=categorical_group，split_rule="mid"，n_samples=2862
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=very_old|L2_education=top，level=2，parent_id=L1_age=very_old，split_name=L2_education，split_type=categorical_group，split_rule="top"，n_samples=754
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=young|L2_education=high，level=2，parent_id=L1_age=young，split_name=L2_education，split_type=categorical_group，split_rule="high"，n_samples=3216
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=young|L2_education=low，level=2，parent_id=L1_age=young，split_name=L2_education，split_type=categorical_group，split_rule="low"，n_samples=146
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=young|L2_education=mid，level=2，parent_id=L1_age=young，split_name=L2_education，split_type=categorical_group，split_rule="mid"，n_samples=2998
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=young|L2_education=others，level=2，parent_id=L1_age=young，split_name=L2_education，split_type=categorical_group，split_rule="others"，n_samples=51
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=mid|L2_education=high|L3_hours-per-week=high_hours，level=3，parent_id=L1_age=mid|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="high_hours"，n_samples=1100
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=mid|L2_education=high|L3_hours-per-week=low_hours，level=3，parent_id=L1_age=mid|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="low_hours"，n_samples=534
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=mid|L2_education=high|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=mid|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=2584
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=mid|L2_education=low|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=mid|L2_education=low，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=140
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=mid|L2_education=low|L3_hours-per-week=others，level=3，parent_id=L1_age=mid|L2_education=low，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="others"，n_samples=73
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=mid|L2_education=mid|L3_hours-per-week=high_hours，level=3，parent_id=L1_age=mid|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="high_hours"，n_samples=739
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=mid|L2_education=mid|L3_hours-per-week=low_hours，level=3，parent_id=L1_age=mid|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="low_hours"，n_samples=470
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=mid|L2_education=mid|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=mid|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=2321
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=mid|L2_education=top|L3_hours-per-week=high_hours，level=3，parent_id=L1_age=mid|L2_education=top，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="high_hours"，n_samples=222
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=mid|L2_education=top|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=mid|L2_education=top，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=259
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=mid|L2_education=top|L3_hours-per-week=others，level=3，parent_id=L1_age=mid|L2_education=top，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="others"，n_samples=72
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=old|L2_education=high|L3_hours-per-week=high_hours，level=3，parent_id=L1_age=old|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="high_hours"，n_samples=1568
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=old|L2_education=high|L3_hours-per-week=low_hours，level=3，parent_id=L1_age=old|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="low_hours"，n_samples=549
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=old|L2_education=high|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=old|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=3211
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=old|L2_education=low|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=old|L2_education=low，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=212
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=old|L2_education=low|L3_hours-per-week=others，level=3，parent_id=L1_age=old|L2_education=low，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="others"，n_samples=116
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=old|L2_education=mid|L3_hours-per-week=high_hours，level=3，parent_id=L1_age=old|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="high_hours"，n_samples=916
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=old|L2_education=mid|L3_hours-per-week=low_hours，level=3，parent_id=L1_age=old|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="low_hours"，n_samples=537
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=old|L2_education=mid|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=old|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=2713
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=old|L2_education=top|L3_hours-per-week=high_hours，level=3，parent_id=L1_age=old|L2_education=top，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="high_hours"，n_samples=566
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=old|L2_education=top|L3_hours-per-week=low_hours，level=3，parent_id=L1_age=old|L2_education=top，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="low_hours"，n_samples=126
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=old|L2_education=top|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=old|L2_education=top，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=662
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=very_old|L2_education=high|L3_hours-per-week=high_hours，level=3，parent_id=L1_age=very_old|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="high_hours"，n_samples=543
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=very_old|L2_education=high|L3_hours-per-week=low_hours，level=3，parent_id=L1_age=very_old|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="low_hours"，n_samples=546
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=very_old|L2_education=high|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=very_old|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=1244
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=very_old|L2_education=low|L3_hours-per-week=low_hours，level=3，parent_id=L1_age=very_old|L2_education=low，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="low_hours"，n_samples=170
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=very_old|L2_education=low|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=very_old|L2_education=low，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=261
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=very_old|L2_education=low|L3_hours-per-week=others，level=3，parent_id=L1_age=very_old|L2_education=low，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="others"，n_samples=80
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=very_old|L2_education=mid|L3_hours-per-week=high_hours，level=3，parent_id=L1_age=very_old|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="high_hours"，n_samples=451
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=very_old|L2_education=mid|L3_hours-per-week=low_hours，level=3，parent_id=L1_age=very_old|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="low_hours"，n_samples=757
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=very_old|L2_education=mid|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=very_old|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=1654
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=very_old|L2_education=top|L3_hours-per-week=high_hours，level=3，parent_id=L1_age=very_old|L2_education=top，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="high_hours"，n_samples=278
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=very_old|L2_education=top|L3_hours-per-week=low_hours，level=3，parent_id=L1_age=very_old|L2_education=top，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="low_hours"，n_samples=153
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=very_old|L2_education=top|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=very_old|L2_education=top，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=323
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=young|L2_education=high|L3_hours-per-week=high_hours，level=3，parent_id=L1_age=young|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="high_hours"，n_samples=291
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=young|L2_education=high|L3_hours-per-week=low_hours，level=3，parent_id=L1_age=young|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="low_hours"，n_samples=1516
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=young|L2_education=high|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=young|L2_education=high，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=1409
# [INFO][BT][2026-03-26 15:29:19] 桶 bucket_id=L1_age=young|L2_education=low 不再细分：3 个子桶样本数不足 min_bucket_size=100
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=young|L2_education=mid|L3_hours-per-week=high_hours，level=3，parent_id=L1_age=young|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="high_hours"，n_samples=267
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=young|L2_education=mid|L3_hours-per-week=low_hours，level=3，parent_id=L1_age=young|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="low_hours"，n_samples=1293
# [INFO][BT][2026-03-26 15:29:19] 创建桶 bucket_id=L1_age=young|L2_education=mid|L3_hours-per-week=normal_hours，level=3，parent_id=L1_age=young|L2_education=mid，split_name=L3_hours-per-week，split_type=numeric_bin，split_rule="normal_hours"，n_samples=1438
# [INFO][BT][2026-03-26 15:29:21] 桶树构建完成：总桶数=61，最大层数=3，叶子桶数=42
# 【INFO】【2026-03-26 15:29:21】【BTTWD】bucket_estimator=none：不训练桶内局部模型，仅使用全局模型概率做桶内阈值搜索
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\bucket_gain.py:27: RuntimeWarning: compute_bucket_score: metric 'F1' is missing or NaN, defaulting to 0.0.
#   warnings.warn(
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\bucket_gain.py:27: RuntimeWarning: compute_bucket_score: metric 'BND_ratio' is missing or NaN, defaulting to 0.0.
#   warnings.warn(
# 【INFO】【2026-03-26 15:29:21】【阈值】桶 ROOT（n_val=1953，source=val) 使用本地阈值 α=0.4000, β=0.2000
# [INFO][BT][2026-03-26 15:29:21] 桶 bucket_id=ROOT level=0：
#     n_train=4557, n_val=1953,
#     BAC=0.784, F1=0.770, AUC=0.937,
#     Regret=0.129, BND_ratio=0.130, POS_coverage=0.260,
#     Score(f1_regret_bnd )=0.576，threshold_source=val
# 【INFO】【2026-03-26 15:29:21】【阈值】桶 L1_age=mid 标记为弱桶，阈值将回退使用 ROOT 的阈值
# [INFO][BT][2026-03-26 15:29:21] 桶 bucket_id=L1_age=mid level=1：
#     n_train=1195, n_val=547,
#     BAC=0.767, F1=0.675, AUC=0.925,
#     Regret=0.119, BND_ratio=0.051, POS_coverage=0.139,
#     Score(f1_regret_bnd )=0.530，threshold_source=val
# [INFO][BT][2026-03-26 15:29:21] 桶 bucket_id=L1_age=mid：
#     parent_id=ROOT，parent_Score=0.576, bucket_Score=0.530,
#     Gain=-0.045, is_weak=True
# 【INFO】【2026-03-26 15:29:22】【阈值】桶 L1_age=old 标记为弱桶，阈值将回退使用 ROOT 的阈值
# [INFO][BT][2026-03-26 15:29:22] 桶 bucket_id=L1_age=old level=1：
#     n_train=1575, n_val=728,
#     BAC=0.765, F1=0.796, AUC=0.930,
#     Regret=0.147, BND_ratio=0.154, POS_coverage=0.354,
#     Score(f1_regret_bnd )=0.573，threshold_source=val
# [INFO][BT][2026-03-26 15:29:22] 桶 bucket_id=L1_age=old：
#     parent_id=ROOT，parent_Score=0.576, bucket_Score=0.573,
#     Gain=-0.003, is_weak=True
# 【INFO】【2026-03-26 15:29:22】【阈值】桶 L1_age=very_old 标记为弱桶，阈值将回退使用 ROOT 的阈值
# [INFO][BT][2026-03-26 15:29:22] 桶 bucket_id=L1_age=very_old level=1：
#     n_train=894, n_val=394,
#     BAC=0.749, F1=0.735, AUC=0.894,
#     Regret=0.193, BND_ratio=0.102, POS_coverage=0.396,
#     Score(f1_regret_bnd )=0.491，threshold_source=val
# [INFO][BT][2026-03-26 15:29:22] 桶 bucket_id=L1_age=very_old：
#     parent_id=ROOT，parent_Score=0.576, bucket_Score=0.491,
#     Gain=-0.085, is_weak=True
# 【INFO】【2026-03-26 15:29:22】【阈值】桶 L1_age=young（n_val=433，source=val) 使用本地阈值 α=0.5000, β=0.4000
# [INFO][BT][2026-03-26 15:29:22] 桶 bucket_id=L1_age=young level=1：
#     n_train=917, n_val=433,
#     BAC=0.746, F1=0.667, AUC=0.935,
#     Regret=0.012, BND_ratio=0.007, POS_coverage=0.007,
#     Score(f1_regret_bnd )=0.651，threshold_source=val
# [INFO][BT][2026-03-26 15:29:22] 桶 bucket_id=L1_age=young：
#     parent_id=ROOT，parent_Score=0.576, bucket_Score=0.651,
#     Gain=+0.075, is_weak=False
# 【INFO】【2026-03-26 15:29:22】【阈值】桶 L1_age=mid|L2_education=high（n_val=250，source=val) 使用本地阈值 α=0.4000, β=0.3000
# [INFO][BT][2026-03-26 15:29:22] 桶 bucket_id=L1_age=mid|L2_education=high level=2：
#     n_train=591, n_val=250,
#     BAC=0.814, F1=0.760, AUC=0.918,
#     Regret=0.133, BND_ratio=0.052, POS_coverage=0.252,
#     Score(f1_regret_bnd )=0.601，threshold_source=val
# [INFO][BT][2026-03-26 15:29:22] 桶 bucket_id=L1_age=mid|L2_education=high：
#     parent_id=L1_age=mid，parent_Score=0.530, bucket_Score=0.601,
#     Gain=+0.070, is_weak=False
# 【INFO】【2026-03-26 15:29:23】【阈值】桶 L1_age=mid|L2_education=low 标记为弱桶，阈值将回退使用 L1_age=mid 的阈值
# [INFO][BT][2026-03-26 15:29:23] 桶 bucket_id=L1_age=mid|L2_education=low level=2：
#     n_train=161, n_val=52,
#     BAC=0.500, F1=0.000, AUC=0.853,
#     Regret=0.028, BND_ratio=0.000, POS_coverage=0.000,
#     Score(f1_regret_bnd )=nan，threshold_source=all
# [INFO][BT][2026-03-26 15:29:23] 桶 bucket_id=L1_age=mid|L2_education=low：
#     parent_id=L1_age=mid，parent_Score=0.530, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2026-03-26 15:29:23】【阈值】桶 L1_age=mid|L2_education=mid 标记为弱桶，阈值将回退使用 L1_age=mid 的阈值
# [INFO][BT][2026-03-26 15:29:23] 桶 bucket_id=L1_age=mid|L2_education=mid level=2：
#     n_train=492, n_val=211,
#     BAC=0.633, F1=0.421, AUC=0.873,
#     Regret=0.078, BND_ratio=0.000, POS_coverage=0.019,
#     Score(f1_regret_bnd )=0.343，threshold_source=val
# [INFO][BT][2026-03-26 15:29:23] 桶 bucket_id=L1_age=mid|L2_education=mid：
#     parent_id=L1_age=mid，parent_Score=0.530, bucket_Score=0.343,
#     Gain=-0.187, is_weak=True
# 【INFO】【2026-03-26 15:29:23】【阈值】桶 L1_age=mid|L2_education=top（n_val=161，source=val) 使用本地阈值 α=0.5000, β=0.3000
# [INFO][BT][2026-03-26 15:29:23] 桶 bucket_id=L1_age=mid|L2_education=top level=2：
#     n_train=116, n_val=161,
#     BAC=0.818, F1=0.857, AUC=0.934,
#     Regret=0.138, BND_ratio=0.075, POS_coverage=0.491,
#     Score(f1_regret_bnd )=0.682，threshold_source=val
# [INFO][BT][2026-03-26 15:29:23] 桶 bucket_id=L1_age=mid|L2_education=top：
#     parent_id=L1_age=mid，parent_Score=0.530, bucket_Score=0.682,
#     Gain=+0.151, is_weak=False
# 【INFO】【2026-03-26 15:29:23】【阈值】桶 L1_age=old|L2_education=high 标记为弱桶，阈值将回退使用 L1_age=old 的阈值
# [INFO][BT][2026-03-26 15:29:23] 桶 bucket_id=L1_age=old|L2_education=high level=2：
#     n_train=745, n_val=318,
#     BAC=0.722, F1=0.753, AUC=0.883,
#     Regret=0.207, BND_ratio=0.126, POS_coverage=0.450,
#     Score(f1_regret_bnd )=0.483，threshold_source=val
# [INFO][BT][2026-03-26 15:29:23] 桶 bucket_id=L1_age=old|L2_education=high：
#     parent_id=L1_age=old，parent_Score=0.573, bucket_Score=0.483,
#     Gain=-0.089, is_weak=True
# 【INFO】【2026-03-26 15:29:24】【阈值】桶 L1_age=old|L2_education=low 标记为弱桶，阈值将回退使用 L1_age=old 的阈值
# [INFO][BT][2026-03-26 15:29:24] 桶 bucket_id=L1_age=old|L2_education=low level=2：
#     n_train=114, n_val=90,
#     BAC=0.489, F1=0.000, AUC=0.824,
#     Regret=0.031, BND_ratio=0.033, POS_coverage=0.000,
#     Score(f1_regret_bnd )=-0.047，threshold_source=val
# [INFO][BT][2026-03-26 15:29:24] 桶 bucket_id=L1_age=old|L2_education=low：
#     parent_id=L1_age=old，parent_Score=0.573, bucket_Score=-0.047,
#     Gain=-0.620, is_weak=True
# 【INFO】【2026-03-26 15:29:24】【阈值】桶 L1_age=old|L2_education=mid 标记为弱桶，阈值将回退使用 L1_age=old 的阈值
# [INFO][BT][2026-03-26 15:29:24] 桶 bucket_id=L1_age=old|L2_education=mid level=2：
#     n_train=584, n_val=248,
#     BAC=0.639, F1=0.626, AUC=0.863,
#     Regret=0.190, BND_ratio=0.218, POS_coverage=0.173,
#     Score(f1_regret_bnd )=0.328，threshold_source=val
# [INFO][BT][2026-03-26 15:29:24] 桶 bucket_id=L1_age=old|L2_education=mid：
#     parent_id=L1_age=old，parent_Score=0.573, bucket_Score=0.328,
#     Gain=-0.245, is_weak=True
# 【INFO】【2026-03-26 15:29:24】【阈值】桶 L1_age=old|L2_education=top（n_val=99，source=val) 使用本地阈值 α=0.4000, β=0.3000
# [INFO][BT][2026-03-26 15:29:24] 桶 bucket_id=L1_age=old|L2_education=top level=2：
#     n_train=270, n_val=99,
#     BAC=0.812, F1=0.908, AUC=0.931,
#     Regret=0.106, BND_ratio=0.030, POS_coverage=0.707,
#     Score(f1_regret_bnd )=0.786，threshold_source=val
# [INFO][BT][2026-03-26 15:29:24] 桶 bucket_id=L1_age=old|L2_education=top：
#     parent_id=L1_age=old，parent_Score=0.573, bucket_Score=0.786,
#     Gain=+0.214, is_weak=False
# 【INFO】【2026-03-26 15:29:24】【阈值】桶 L1_age=very_old|L2_education=high 标记为弱桶，阈值将回退使用 L1_age=very_old 的阈值
# [INFO][BT][2026-03-26 15:29:24] 桶 bucket_id=L1_age=very_old|L2_education=high level=2：
#     n_train=322, n_val=143,
#     BAC=0.734, F1=0.731, AUC=0.855,
#     Regret=0.227, BND_ratio=0.063, POS_coverage=0.517,
#     Score(f1_regret_bnd )=0.473，threshold_source=val
# [INFO][BT][2026-03-26 15:29:24] 桶 bucket_id=L1_age=very_old|L2_education=high：
#     parent_id=L1_age=very_old，parent_Score=0.491, bucket_Score=0.473,
#     Gain=-0.018, is_weak=True
# 【INFO】【2026-03-26 15:29:24】【阈值】桶 L1_age=very_old|L2_education=low 标记为弱桶，阈值将回退使用 L1_age=very_old 的阈值
# [INFO][BT][2026-03-26 15:29:24] 桶 bucket_id=L1_age=very_old|L2_education=low level=2：
#     n_train=118, n_val=144,
#     BAC=0.591, F1=0.308, AUC=0.841,
#     Regret=0.094, BND_ratio=0.000, POS_coverage=0.014,
#     Score(f1_regret_bnd )=0.214，threshold_source=val
# [INFO][BT][2026-03-26 15:29:24] 桶 bucket_id=L1_age=very_old|L2_education=low：
#     parent_id=L1_age=very_old，parent_Score=0.491, bucket_Score=0.214,
#     Gain=-0.277, is_weak=True
# 【INFO】【2026-03-26 15:29:25】【阈值】桶 L1_age=very_old|L2_education=mid 标记为弱桶，阈值将回退使用 L1_age=very_old 的阈值
# [INFO][BT][2026-03-26 15:29:25] 桶 bucket_id=L1_age=very_old|L2_education=mid level=2：
#     n_train=396, n_val=173,
#     BAC=0.623, F1=0.594, AUC=0.870,
#     Regret=0.178, BND_ratio=0.231, POS_coverage=0.127,
#     Score(f1_regret_bnd )=0.300，threshold_source=val
# [INFO][BT][2026-03-26 15:29:25] 桶 bucket_id=L1_age=very_old|L2_education=mid：
#     parent_id=L1_age=very_old，parent_Score=0.491, bucket_Score=0.300,
#     Gain=-0.191, is_weak=True
# 【INFO】【2026-03-26 15:29:25】【阈值】桶 L1_age=very_old|L2_education=top（n_val=246，source=val) 使用本地阈值 α=0.4000, β=0.3000
# [INFO][BT][2026-03-26 15:29:25] 桶 bucket_id=L1_age=very_old|L2_education=top level=2：
#     n_train=179, n_val=246,
#     BAC=0.708, F1=0.879, AUC=0.885,
#     Regret=0.152, BND_ratio=0.065, POS_coverage=0.764,
#     Score(f1_regret_bnd )=0.694，threshold_source=val
# [INFO][BT][2026-03-26 15:29:25] 桶 bucket_id=L1_age=very_old|L2_education=top：
#     parent_id=L1_age=very_old，parent_Score=0.491, bucket_Score=0.694,
#     Gain=+0.203, is_weak=False
# 【INFO】【2026-03-26 15:29:25】【阈值】桶 L1_age=young|L2_education=high 标记为弱桶，阈值将回退使用 L1_age=young 的阈值
# [INFO][BT][2026-03-26 15:29:25] 桶 bucket_id=L1_age=young|L2_education=high level=2：
#     n_train=446, n_val=273,
#     BAC=0.721, F1=0.600, AUC=0.970,
#     Regret=0.042, BND_ratio=0.018, POS_coverage=0.026,
#     Score(f1_regret_bnd )=0.549，threshold_source=val
# [INFO][BT][2026-03-26 15:29:25] 桶 bucket_id=L1_age=young|L2_education=high：
#     parent_id=L1_age=young，parent_Score=0.651, bucket_Score=0.549,
#     Gain=-0.102, is_weak=True
# 【INFO】【2026-03-26 15:29:25】【阈值】桶 L1_age=young|L2_education=low 标记为弱桶，阈值将回退使用 L1_age=young 的阈值
# [INFO][BT][2026-03-26 15:29:25] 桶 bucket_id=L1_age=young|L2_education=low level=2：
#     n_train=109, n_val=37,
#     BAC=0.667, F1=0.500, AUC=0.942,
#     Regret=0.021, BND_ratio=0.000, POS_coverage=0.007,
#     Score(f1_regret_bnd )=nan，threshold_source=all
# [INFO][BT][2026-03-26 15:29:25] 桶 bucket_id=L1_age=young|L2_education=low：
#     parent_id=L1_age=young，parent_Score=0.651, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2026-03-26 15:29:25】【阈值】桶 L1_age=young|L2_education=mid 标记为弱桶，阈值将回退使用 L1_age=young 的阈值
# [INFO][BT][2026-03-26 15:29:25] 桶 bucket_id=L1_age=young|L2_education=mid level=2：
#     n_train=413, n_val=247,
#     BAC=0.583, F1=0.286, AUC=0.967,
#     Regret=0.027, BND_ratio=0.004, POS_coverage=0.004,
#     Score(f1_regret_bnd )=0.256，threshold_source=val
# [INFO][BT][2026-03-26 15:29:25] 桶 bucket_id=L1_age=young|L2_education=mid：
#     parent_id=L1_age=young，parent_Score=0.651, bucket_Score=0.256,
#     Gain=-0.395, is_weak=True
# 【INFO】【2026-03-26 15:29:26】【阈值】桶 L1_age=young|L2_education=others 标记为弱桶，阈值将回退使用 L1_age=young 的阈值
# [INFO][BT][2026-03-26 15:29:26] 桶 bucket_id=L1_age=young|L2_education=others level=2：
#     n_train=37, n_val=14,
#     BAC=0.864, F1=0.857, AUC=0.936,
#     Regret=0.034, BND_ratio=0.020, POS_coverage=0.059,
#     Score(f1_regret_bnd )=nan，threshold_source=all
# [INFO][BT][2026-03-26 15:29:26] 桶 bucket_id=L1_age=young|L2_education=others：
#     parent_id=L1_age=young，parent_Score=0.651, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2026-03-26 15:29:26】【阈值】桶 L1_age=mid|L2_education=high|L3_hours-per-week=high_hours 标记为弱桶，阈值将回退使用 L1_age=mid|L2_education=high 的阈值
# [INFO][BT][2026-03-26 15:29:26] 桶 bucket_id=L1_age=mid|L2_education=high|L3_hours-per-week=high_hours level=3：
#     n_train=794, n_val=306,
#     BAC=0.664, F1=0.733, AUC=0.861,
#     Regret=0.223, BND_ratio=0.206, POS_coverage=0.395,
#     Score(f1_regret_bnd )=0.407，threshold_source=val
# [INFO][BT][2026-03-26 15:29:26] 桶 bucket_id=L1_age=mid|L2_education=high|L3_hours-per-week=high_hours：
#     parent_id=L1_age=mid|L2_education=high，parent_Score=0.601, bucket_Score=0.407,
#     Gain=-0.194, is_weak=True
# 【INFO】【2026-03-26 15:29:26】【阈值】桶 L1_age=mid|L2_education=high|L3_hours-per-week=low_hours 标记为弱桶，阈值将回退使用 L1_age=mid|L2_education=high 的阈值
# [INFO][BT][2026-03-26 15:29:26] 桶 bucket_id=L1_age=mid|L2_education=high|L3_hours-per-week=low_hours level=3：
#     n_train=365, n_val=169,
#     BAC=0.725, F1=0.667, AUC=0.934,
#     Regret=0.086, BND_ratio=0.089, POS_coverage=0.071,
#     Score(f1_regret_bnd )=0.536，threshold_source=val
# [INFO][BT][2026-03-26 15:29:26] 桶 bucket_id=L1_age=mid|L2_education=high|L3_hours-per-week=low_hours：
#     parent_id=L1_age=mid|L2_education=high，parent_Score=0.601, bucket_Score=0.536,
#     Gain=-0.064, is_weak=True
# 【INFO】【2026-03-26 15:29:26】【阈值】桶 L1_age=mid|L2_education=high|L3_hours-per-week=normal_hours 标记为弱桶，阈值将回退使用 L1_age=mid|L2_education=high 的阈值
# [INFO][BT][2026-03-26 15:29:26] 桶 bucket_id=L1_age=mid|L2_education=high|L3_hours-per-week=normal_hours level=3：
#     n_train=1804, n_val=780,
#     BAC=0.775, F1=0.671, AUC=0.900,
#     Regret=0.149, BND_ratio=0.055, POS_coverage=0.226,
#     Score(f1_regret_bnd )=0.494，threshold_source=val
# [INFO][BT][2026-03-26 15:29:26] 桶 bucket_id=L1_age=mid|L2_education=high|L3_hours-per-week=normal_hours：
#     parent_id=L1_age=mid|L2_education=high，parent_Score=0.601, bucket_Score=0.494,
#     Gain=-0.107, is_weak=True
# 【INFO】【2026-03-26 15:29:27】【阈值】桶 L1_age=mid|L2_education=low|L3_hours-per-week=normal_hours 标记为弱桶，阈值将回退使用 L1_age=mid|L2_education=low 的阈值
# [INFO][BT][2026-03-26 15:29:27] 桶 bucket_id=L1_age=mid|L2_education=low|L3_hours-per-week=normal_hours level=3：
#     n_train=98, n_val=42,
#     BAC=0.500, F1=0.000, AUC=0.800,
#     Regret=0.032, BND_ratio=0.000, POS_coverage=0.000,
#     Score(f1_regret_bnd )=nan，threshold_source=all
# [INFO][BT][2026-03-26 15:29:27] 桶 bucket_id=L1_age=mid|L2_education=low|L3_hours-per-week=normal_hours：
#     parent_id=L1_age=mid|L2_education=low，parent_Score=-0.136, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2026-03-26 15:29:27】【阈值】桶 L1_age=mid|L2_education=low|L3_hours-per-week=others 标记为弱桶，阈值将回退使用 L1_age=mid|L2_education=low 的阈值
# [INFO][BT][2026-03-26 15:29:27] 桶 bucket_id=L1_age=mid|L2_education=low|L3_hours-per-week=others level=3：
#     n_train=63, n_val=10,
#     BAC=0.500, F1=0.000, AUC=0.972,
#     Regret=0.021, BND_ratio=0.000, POS_coverage=0.000,
#     Score(f1_regret_bnd )=nan，threshold_source=all
# [INFO][BT][2026-03-26 15:29:27] 桶 bucket_id=L1_age=mid|L2_education=low|L3_hours-per-week=others：
#     parent_id=L1_age=mid|L2_education=low，parent_Score=-0.136, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2026-03-26 15:29:27】【阈值】桶 L1_age=mid|L2_education=mid|L3_hours-per-week=high_hours 标记为弱桶，阈值将回退使用 L1_age=mid|L2_education=mid 的阈值
# [INFO][BT][2026-03-26 15:29:27] 桶 bucket_id=L1_age=mid|L2_education=mid|L3_hours-per-week=high_hours level=3：
#     n_train=533, n_val=206,
#     BAC=0.503, F1=0.359, AUC=0.767,
#     Regret=0.180, BND_ratio=0.243, POS_coverage=0.034,
#     Score(f1_regret_bnd )=0.058，threshold_source=val
# [INFO][BT][2026-03-26 15:29:27] 桶 bucket_id=L1_age=mid|L2_education=mid|L3_hours-per-week=high_hours：
#     parent_id=L1_age=mid|L2_education=mid，parent_Score=0.343, bucket_Score=0.058,
#     Gain=-0.285, is_weak=True
# 【INFO】【2026-03-26 15:29:27】【阈值】桶 L1_age=mid|L2_education=mid|L3_hours-per-week=low_hours（n_val=144，source=val) 使用本地阈值 α=0.4000, β=0.3000
# [INFO][BT][2026-03-26 15:29:27] 桶 bucket_id=L1_age=mid|L2_education=mid|L3_hours-per-week=low_hours level=3：
#     n_train=326, n_val=144,
#     BAC=0.833, F1=0.800, AUC=0.978,
#     Regret=0.021, BND_ratio=0.000, POS_coverage=0.028,
#     Score(f1_regret_bnd )=0.779，threshold_source=val
# [INFO][BT][2026-03-26 15:29:27] 桶 bucket_id=L1_age=mid|L2_education=mid|L3_hours-per-week=low_hours：
#     parent_id=L1_age=mid|L2_education=mid，parent_Score=0.343, bucket_Score=0.779,
#     Gain=+0.436, is_weak=False
# 【INFO】【2026-03-26 15:29:27】【阈值】桶 L1_age=mid|L2_education=mid|L3_hours-per-week=normal_hours 标记为弱桶，阈值将回退使用 L1_age=mid|L2_education=mid 的阈值
# [INFO][BT][2026-03-26 15:29:27] 桶 bucket_id=L1_age=mid|L2_education=mid|L3_hours-per-week=normal_hours level=3：
#     n_train=1607, n_val=714,
#     BAC=0.573, F1=0.286, AUC=0.877,
#     Regret=0.083, BND_ratio=0.028, POS_coverage=0.011,
#     Score(f1_regret_bnd )=0.189，threshold_source=val
# [INFO][BT][2026-03-26 15:29:27] 桶 bucket_id=L1_age=mid|L2_education=mid|L3_hours-per-week=normal_hours：
#     parent_id=L1_age=mid|L2_education=mid，parent_Score=0.343, bucket_Score=0.189,
#     Gain=-0.154, is_weak=True
# 【INFO】【2026-03-26 15:29:28】【阈值】桶 L1_age=mid|L2_education=top|L3_hours-per-week=high_hours（n_val=61，source=val) 使用本地阈值 α=0.6000, β=0.5000
# [INFO][BT][2026-03-26 15:29:28] 桶 bucket_id=L1_age=mid|L2_education=top|L3_hours-per-week=high_hours level=3：
#     n_train=161, n_val=61,
#     BAC=0.808, F1=0.873, AUC=0.893,
#     Regret=0.168, BND_ratio=0.033, POS_coverage=0.590,
#     Score(f1_regret_bnd )=0.689，threshold_source=val
# [INFO][BT][2026-03-26 15:29:28] 桶 bucket_id=L1_age=mid|L2_education=top|L3_hours-per-week=high_hours：
#     parent_id=L1_age=mid|L2_education=top，parent_Score=0.682, bucket_Score=0.689,
#     Gain=+0.007, is_weak=False
# 【INFO】【2026-03-26 15:29:28】【阈值】桶 L1_age=mid|L2_education=top|L3_hours-per-week=normal_hours（n_val=76，source=val) 使用本地阈值 α=0.5000, β=0.3000
# [INFO][BT][2026-03-26 15:29:28] 桶 bucket_id=L1_age=mid|L2_education=top|L3_hours-per-week=normal_hours level=3：
#     n_train=183, n_val=76,
#     BAC=0.846, F1=0.857, AUC=0.943,
#     Regret=0.115, BND_ratio=0.066, POS_coverage=0.474,
#     Score(f1_regret_bnd )=0.709，threshold_source=val
# [INFO][BT][2026-03-26 15:29:28] 桶 bucket_id=L1_age=mid|L2_education=top|L3_hours-per-week=normal_hours：
#     parent_id=L1_age=mid|L2_education=top，parent_Score=0.682, bucket_Score=0.709,
#     Gain=+0.027, is_weak=False
# 【INFO】【2026-03-26 15:29:28】【阈值】桶 L1_age=mid|L2_education=top|L3_hours-per-week=others 标记为弱桶，阈值将回退使用 L1_age=mid|L2_education=top 的阈值
# [INFO][BT][2026-03-26 15:29:28] 桶 bucket_id=L1_age=mid|L2_education=top|L3_hours-per-week=others level=3：
#     n_train=48, n_val=24,
#     BAC=0.923, F1=0.917, AUC=0.975,
#     Regret=0.042, BND_ratio=0.000, POS_coverage=0.153,
#     Score(f1_regret_bnd )=nan，threshold_source=all
# [INFO][BT][2026-03-26 15:29:28] 桶 bucket_id=L1_age=mid|L2_education=top|L3_hours-per-week=others：
#     parent_id=L1_age=mid|L2_education=top，parent_Score=0.682, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2026-03-26 15:29:28】【阈值】桶 L1_age=old|L2_education=high|L3_hours-per-week=high_hours（n_val=490，source=val) 使用本地阈值 α=0.4000, β=0.3000
# [INFO][BT][2026-03-26 15:29:28] 桶 bucket_id=L1_age=old|L2_education=high|L3_hours-per-week=high_hours level=3：
#     n_train=1078, n_val=490,
#     BAC=0.698, F1=0.809, AUC=0.851,
#     Regret=0.215, BND_ratio=0.073, POS_coverage=0.665,
#     Score(f1_regret_bnd )=0.557，threshold_source=val
# [INFO][BT][2026-03-26 15:29:28] 桶 bucket_id=L1_age=old|L2_education=high|L3_hours-per-week=high_hours：
#     parent_id=L1_age=old|L2_education=high，parent_Score=0.483, bucket_Score=0.557,
#     Gain=+0.074, is_weak=False
# 【INFO】【2026-03-26 15:29:29】【阈值】桶 L1_age=old|L2_education=high|L3_hours-per-week=low_hours（n_val=160，source=val) 使用本地阈值 α=0.5000, β=0.4000
# [INFO][BT][2026-03-26 15:29:29] 桶 bucket_id=L1_age=old|L2_education=high|L3_hours-per-week=low_hours level=3：
#     n_train=389, n_val=160,
#     BAC=0.819, F1=0.769, AUC=0.953,
#     Regret=0.113, BND_ratio=0.037, POS_coverage=0.181,
#     Score(f1_regret_bnd )=0.638，threshold_source=val
# [INFO][BT][2026-03-26 15:29:29] 桶 bucket_id=L1_age=old|L2_education=high|L3_hours-per-week=low_hours：
#     parent_id=L1_age=old|L2_education=high，parent_Score=0.483, bucket_Score=0.638,
#     Gain=+0.155, is_weak=False
# 【INFO】【2026-03-26 15:29:29】【阈值】桶 L1_age=old|L2_education=high|L3_hours-per-week=normal_hours（n_val=944，source=val) 使用本地阈值 α=0.4000, β=0.2000
# [INFO][BT][2026-03-26 15:29:29] 桶 bucket_id=L1_age=old|L2_education=high|L3_hours-per-week=normal_hours level=3：
#     n_train=2267, n_val=944,
#     BAC=0.736, F1=0.762, AUC=0.896,
#     Regret=0.186, BND_ratio=0.133, POS_coverage=0.446,
#     Score(f1_regret_bnd )=0.509，threshold_source=val
# [INFO][BT][2026-03-26 15:29:29] 桶 bucket_id=L1_age=old|L2_education=high|L3_hours-per-week=normal_hours：
#     parent_id=L1_age=old|L2_education=high，parent_Score=0.483, bucket_Score=0.509,
#     Gain=+0.026, is_weak=False
# 【INFO】【2026-03-26 15:29:29】【阈值】桶 L1_age=old|L2_education=low|L3_hours-per-week=normal_hours（n_val=57，source=val) 使用本地阈值 α=0.4000, β=0.3000
# [INFO][BT][2026-03-26 15:29:29] 桶 bucket_id=L1_age=old|L2_education=low|L3_hours-per-week=normal_hours level=3：
#     n_train=155, n_val=57,
#     BAC=0.500, F1=0.000, AUC=0.661,
#     Regret=0.026, BND_ratio=0.000, POS_coverage=0.000,
#     Score(f1_regret_bnd )=-0.026，threshold_source=val
# [INFO][BT][2026-03-26 15:29:29] 桶 bucket_id=L1_age=old|L2_education=low|L3_hours-per-week=normal_hours：
#     parent_id=L1_age=old|L2_education=low，parent_Score=-0.047, bucket_Score=-0.026,
#     Gain=+0.021, is_weak=False
# 【INFO】【2026-03-26 15:29:29】【阈值】桶 L1_age=old|L2_education=low|L3_hours-per-week=others 标记为弱桶，阈值将回退使用 L1_age=old|L2_education=low 的阈值
# [INFO][BT][2026-03-26 15:29:29] 桶 bucket_id=L1_age=old|L2_education=low|L3_hours-per-week=others level=3：
#     n_train=83, n_val=33,
#     BAC=0.848, F1=0.696, AUC=0.968,
#     Regret=0.065, BND_ratio=0.060, POS_coverage=0.112,
#     Score(f1_regret_bnd )=nan，threshold_source=all
# [INFO][BT][2026-03-26 15:29:29] 桶 bucket_id=L1_age=old|L2_education=low|L3_hours-per-week=others：
#     parent_id=L1_age=old|L2_education=low，parent_Score=-0.047, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2026-03-26 15:29:30】【阈值】桶 L1_age=old|L2_education=mid|L3_hours-per-week=high_hours 标记为弱桶，阈值将回退使用 L1_age=old|L2_education=mid 的阈值
# [INFO][BT][2026-03-26 15:29:30] 桶 bucket_id=L1_age=old|L2_education=mid|L3_hours-per-week=high_hours level=3：
#     n_train=626, n_val=290,
#     BAC=0.602, F1=0.630, AUC=0.827,
#     Regret=0.254, BND_ratio=0.245, POS_coverage=0.310,
#     Score(f1_regret_bnd )=0.254，threshold_source=val
# [INFO][BT][2026-03-26 15:29:30] 桶 bucket_id=L1_age=old|L2_education=mid|L3_hours-per-week=high_hours：
#     parent_id=L1_age=old|L2_education=mid，parent_Score=0.328, bucket_Score=0.254,
#     Gain=-0.074, is_weak=True
# 【INFO】【2026-03-26 15:29:30】【阈值】桶 L1_age=old|L2_education=mid|L3_hours-per-week=low_hours 标记为弱桶，阈值将回退使用 L1_age=old|L2_education=mid 的阈值
# [INFO][BT][2026-03-26 15:29:30] 桶 bucket_id=L1_age=old|L2_education=mid|L3_hours-per-week=low_hours level=3：
#     n_train=386, n_val=151,
#     BAC=0.552, F1=0.308, AUC=0.902,
#     Regret=0.083, BND_ratio=0.106, POS_coverage=0.013,
#     Score(f1_regret_bnd )=0.172，threshold_source=val
# [INFO][BT][2026-03-26 15:29:30] 桶 bucket_id=L1_age=old|L2_education=mid|L3_hours-per-week=low_hours：
#     parent_id=L1_age=old|L2_education=mid，parent_Score=0.328, bucket_Score=0.172,
#     Gain=-0.156, is_weak=True
# 【INFO】【2026-03-26 15:29:30】【阈值】桶 L1_age=old|L2_education=mid|L3_hours-per-week=normal_hours 标记为弱桶，阈值将回退使用 L1_age=old|L2_education=mid 的阈值
# [INFO][BT][2026-03-26 15:29:30] 桶 bucket_id=L1_age=old|L2_education=mid|L3_hours-per-week=normal_hours level=3：
#     n_train=1910, n_val=803,
#     BAC=0.592, F1=0.563, AUC=0.867,
#     Regret=0.190, BND_ratio=0.264, POS_coverage=0.154,
#     Score(f1_regret_bnd )=0.240，threshold_source=val
# [INFO][BT][2026-03-26 15:29:30] 桶 bucket_id=L1_age=old|L2_education=mid|L3_hours-per-week=normal_hours：
#     parent_id=L1_age=old|L2_education=mid，parent_Score=0.328, bucket_Score=0.240,
#     Gain=-0.087, is_weak=True
# 【INFO】【2026-03-26 15:29:30】【阈值】桶 L1_age=old|L2_education=top|L3_hours-per-week=high_hours 标记为弱桶，阈值将回退使用 L1_age=old|L2_education=top 的阈值
# [INFO][BT][2026-03-26 15:29:30] 桶 bucket_id=L1_age=old|L2_education=top|L3_hours-per-week=high_hours level=3：
#     n_train=402, n_val=164,
#     BAC=0.658, F1=0.909, AUC=0.884,
#     Regret=0.123, BND_ratio=0.043, POS_coverage=0.866,
#     Score(f1_regret_bnd )=0.764，threshold_source=val
# [INFO][BT][2026-03-26 15:29:30] 桶 bucket_id=L1_age=old|L2_education=top|L3_hours-per-week=high_hours：
#     parent_id=L1_age=old|L2_education=top，parent_Score=0.786, bucket_Score=0.764,
#     Gain=-0.022, is_weak=True
# 【INFO】【2026-03-26 15:29:30】【阈值】桶 L1_age=old|L2_education=top|L3_hours-per-week=low_hours（n_val=35，source=val) 使用本地阈值 α=0.4000, β=0.3000
# [INFO][BT][2026-03-26 15:29:30] 桶 bucket_id=L1_age=old|L2_education=top|L3_hours-per-week=low_hours level=3：
#     n_train=91, n_val=35,
#     BAC=0.917, F1=0.944, AUC=0.948,
#     Regret=0.050, BND_ratio=0.029, POS_coverage=0.543,
#     Score(f1_regret_bnd )=0.880，threshold_source=val
# [INFO][BT][2026-03-26 15:29:30] 桶 bucket_id=L1_age=old|L2_education=top|L3_hours-per-week=low_hours：
#     parent_id=L1_age=old|L2_education=top，parent_Score=0.786, bucket_Score=0.880,
#     Gain=+0.094, is_weak=False
# 【INFO】【2026-03-26 15:29:31】【阈值】桶 L1_age=old|L2_education=top|L3_hours-per-week=normal_hours 标记为弱桶，阈值将回退使用 L1_age=old|L2_education=top 的阈值
# [INFO][BT][2026-03-26 15:29:31] 桶 bucket_id=L1_age=old|L2_education=top|L3_hours-per-week=normal_hours level=3：
#     n_train=498, n_val=164,
#     BAC=0.737, F1=0.890, AUC=0.864,
#     Regret=0.145, BND_ratio=0.043, POS_coverage=0.762,
#     Score(f1_regret_bnd )=0.724，threshold_source=val
# [INFO][BT][2026-03-26 15:29:31] 桶 bucket_id=L1_age=old|L2_education=top|L3_hours-per-week=normal_hours：
#     parent_id=L1_age=old|L2_education=top，parent_Score=0.786, bucket_Score=0.724,
#     Gain=-0.063, is_weak=True
# 【INFO】【2026-03-26 15:29:31】【阈值】桶 L1_age=very_old|L2_education=high|L3_hours-per-week=high_hours（n_val=185，source=val) 使用本地阈值 α=0.4000, β=0.3000
# [INFO][BT][2026-03-26 15:29:31] 桶 bucket_id=L1_age=very_old|L2_education=high|L3_hours-per-week=high_hours level=3：
#     n_train=358, n_val=185,
#     BAC=0.659, F1=0.795, AUC=0.836,
#     Regret=0.231, BND_ratio=0.114, POS_coverage=0.643,
#     Score(f1_regret_bnd )=0.507，threshold_source=val
# [INFO][BT][2026-03-26 15:29:31] 桶 bucket_id=L1_age=very_old|L2_education=high|L3_hours-per-week=high_hours：
#     parent_id=L1_age=very_old|L2_education=high，parent_Score=0.473, bucket_Score=0.507,
#     Gain=+0.034, is_weak=False
# 【INFO】【2026-03-26 15:29:31】【阈值】桶 L1_age=very_old|L2_education=high|L3_hours-per-week=low_hours 标记为弱桶，阈值将回退使用 L1_age=very_old|L2_education=high 的阈值
# [INFO][BT][2026-03-26 15:29:31] 桶 bucket_id=L1_age=very_old|L2_education=high|L3_hours-per-week=low_hours level=3：
#     n_train=391, n_val=155,
#     BAC=0.498, F1=0.444, AUC=0.835,
#     Regret=0.197, BND_ratio=0.355, POS_coverage=0.071,
#     Score(f1_regret_bnd )=0.070，threshold_source=val
# [INFO][BT][2026-03-26 15:29:31] 桶 bucket_id=L1_age=very_old|L2_education=high|L3_hours-per-week=low_hours：
#     parent_id=L1_age=very_old|L2_education=high，parent_Score=0.473, bucket_Score=0.070,
#     Gain=-0.402, is_weak=True
# 【INFO】【2026-03-26 15:29:31】【阈值】桶 L1_age=very_old|L2_education=high|L3_hours-per-week=normal_hours（n_val=377，source=val) 使用本地阈值 α=0.4000, β=0.3000
# [INFO][BT][2026-03-26 15:29:31] 桶 bucket_id=L1_age=very_old|L2_education=high|L3_hours-per-week=normal_hours level=3：
#     n_train=867, n_val=377,
#     BAC=0.740, F1=0.779, AUC=0.870,
#     Regret=0.205, BND_ratio=0.061, POS_coverage=0.597,
#     Score(f1_regret_bnd )=0.543，threshold_source=val
# [INFO][BT][2026-03-26 15:29:31] 桶 bucket_id=L1_age=very_old|L2_education=high|L3_hours-per-week=normal_hours：
#     parent_id=L1_age=very_old|L2_education=high，parent_Score=0.473, bucket_Score=0.543,
#     Gain=+0.071, is_weak=False
# 【INFO】【2026-03-26 15:29:32】【阈值】桶 L1_age=very_old|L2_education=low|L3_hours-per-week=low_hours 标记为弱桶，阈值将回退使用 L1_age=very_old|L2_education=low 的阈值
# [INFO][BT][2026-03-26 15:29:32] 桶 bucket_id=L1_age=very_old|L2_education=low|L3_hours-per-week=low_hours level=3：
#     n_train=125, n_val=45,
#     BAC=0.500, F1=0.000, AUC=0.864,
#     Regret=0.033, BND_ratio=0.000, POS_coverage=0.000,
#     Score(f1_regret_bnd )=-0.033，threshold_source=val
# [INFO][BT][2026-03-26 15:29:32] 桶 bucket_id=L1_age=very_old|L2_education=low|L3_hours-per-week=low_hours：
#     parent_id=L1_age=very_old|L2_education=low，parent_Score=0.214, bucket_Score=-0.033,
#     Gain=-0.247, is_weak=True
# 【INFO】【2026-03-26 15:29:32】【阈值】桶 L1_age=very_old|L2_education=low|L3_hours-per-week=normal_hours 标记为弱桶，阈值将回退使用 L1_age=very_old|L2_education=low 的阈值
# [INFO][BT][2026-03-26 15:29:32] 桶 bucket_id=L1_age=very_old|L2_education=low|L3_hours-per-week=normal_hours level=3：
#     n_train=186, n_val=75,
#     BAC=0.493, F1=0.000, AUC=0.751,
#     Regret=0.093, BND_ratio=0.027, POS_coverage=0.000,
#     Score(f1_regret_bnd )=-0.107，threshold_source=val
# [INFO][BT][2026-03-26 15:29:32] 桶 bucket_id=L1_age=very_old|L2_education=low|L3_hours-per-week=normal_hours：
#     parent_id=L1_age=very_old|L2_education=low，parent_Score=0.214, bucket_Score=-0.107,
#     Gain=-0.321, is_weak=True
# 【INFO】【2026-03-26 15:29:32】【阈值】桶 L1_age=very_old|L2_education=low|L3_hours-per-week=others 标记为弱桶，阈值将回退使用 L1_age=very_old|L2_education=low 的阈值
# [INFO][BT][2026-03-26 15:29:32] 桶 bucket_id=L1_age=very_old|L2_education=low|L3_hours-per-week=others level=3：
#     n_train=56, n_val=24,
#     BAC=0.669, F1=0.571, AUC=0.851,
#     Regret=0.147, BND_ratio=0.100, POS_coverage=0.087,
#     Score(f1_regret_bnd )=nan，threshold_source=all
# [INFO][BT][2026-03-26 15:29:32] 桶 bucket_id=L1_age=very_old|L2_education=low|L3_hours-per-week=others：
#     parent_id=L1_age=very_old|L2_education=low，parent_Score=0.214, bucket_Score=nan,
#     Gain=+nan, is_weak=True
# 【INFO】【2026-03-26 15:29:32】【阈值】桶 L1_age=very_old|L2_education=mid|L3_hours-per-week=high_hours 标记为弱桶，阈值将回退使用 L1_age=very_old|L2_education=mid 的阈值
# [INFO][BT][2026-03-26 15:29:32] 桶 bucket_id=L1_age=very_old|L2_education=mid|L3_hours-per-week=high_hours level=3：
#     n_train=312, n_val=139,
#     BAC=0.478, F1=0.513, AUC=0.755,
#     Regret=0.311, BND_ratio=0.367, POS_coverage=0.216,
#     Score(f1_regret_bnd )=0.018，threshold_source=val
# [INFO][BT][2026-03-26 15:29:32] 桶 bucket_id=L1_age=very_old|L2_education=mid|L3_hours-per-week=high_hours：
#     parent_id=L1_age=very_old|L2_education=mid，parent_Score=0.300, bucket_Score=0.018,
#     Gain=-0.282, is_weak=True
# 【INFO】【2026-03-26 15:29:32】【阈值】桶 L1_age=very_old|L2_education=mid|L3_hours-per-week=low_hours（n_val=223，source=val) 使用本地阈值 α=0.5000, β=0.4000
# [INFO][BT][2026-03-26 15:29:32] 桶 bucket_id=L1_age=very_old|L2_education=mid|L3_hours-per-week=low_hours level=3：
#     n_train=534, n_val=223,
#     BAC=0.703, F1=0.583, AUC=0.840,
#     Regret=0.068, BND_ratio=0.004, POS_coverage=0.031,
#     Score(f1_regret_bnd )=0.513，threshold_source=val
# [INFO][BT][2026-03-26 15:29:32] 桶 bucket_id=L1_age=very_old|L2_education=mid|L3_hours-per-week=low_hours：
#     parent_id=L1_age=very_old|L2_education=mid，parent_Score=0.300, bucket_Score=0.513,
#     Gain=+0.212, is_weak=False
# 【INFO】【2026-03-26 15:29:33】【阈值】桶 L1_age=very_old|L2_education=mid|L3_hours-per-week=normal_hours 标记为弱桶，阈值将回退使用 L1_age=very_old|L2_education=mid 的阈值
# [INFO][BT][2026-03-26 15:29:33] 桶 bucket_id=L1_age=very_old|L2_education=mid|L3_hours-per-week=normal_hours level=3：
#     n_train=1142, n_val=512,
#     BAC=0.564, F1=0.497, AUC=0.858,
#     Regret=0.198, BND_ratio=0.250, POS_coverage=0.100,
#     Score(f1_regret_bnd )=0.174，threshold_source=val
# ...
#     Score(f1_regret_bnd )=nan，threshold_source=val
# [INFO][BT][2026-03-26 15:29:55] 桶 bucket_id=L1_age=very_old|L2_education=top|L3_hours-per-week=normal_hours：
#     parent_id=L1_age=very_old|L2_education=top，parent_Score=nan, bucket_Score=nan,
#     Gain=+nan, is_weak=False
# 【INFO】【2026-03-26 15:29:56】【阈值】桶 L1_age=young|L2_education=high|L3_hours-per-week=high_hours（n_val=96，source=val) 使用本地阈值 α=0.5000, β=0.1000
# [INFO][BT][2026-03-26 15:29:56] 桶 bucket_id=L1_age=young|L2_education=high|L3_hours-per-week=high_hours level=3：
#     n_train=195, n_val=96,
#     BAC=0.626, F1=0.500, AUC=0.946,
#     Regret=0.089, BND_ratio=0.104, POS_coverage=0.031,
#     Score(f1_regret_bnd )=nan，threshold_source=val
# [INFO][BT][2026-03-26 15:29:56] 桶 bucket_id=L1_age=young|L2_education=high|L3_hours-per-week=high_hours：
#     parent_id=L1_age=young|L2_education=high，parent_Score=nan, bucket_Score=nan,
#     Gain=+nan, is_weak=False
# 【INFO】【2026-03-26 15:29:56】【阈值】桶 L1_age=young|L2_education=high|L3_hours-per-week=low_hours（n_val=466，source=val) 使用本地阈值 α=0.4000, β=0.3000
# [INFO][BT][2026-03-26 15:29:56] 桶 bucket_id=L1_age=young|L2_education=high|L3_hours-per-week=low_hours level=3：
#     n_train=1050, n_val=466,
#     BAC=0.500, F1=0.000, AUC=0.917,
#     Regret=0.006, BND_ratio=0.000, POS_coverage=0.000,
#     Score(f1_regret_bnd )=nan，threshold_source=val
# [INFO][BT][2026-03-26 15:29:56] 桶 bucket_id=L1_age=young|L2_education=high|L3_hours-per-week=low_hours：
#     parent_id=L1_age=young|L2_education=high，parent_Score=nan, bucket_Score=nan,
#     Gain=+nan, is_weak=False
# 【INFO】【2026-03-26 15:29:56】【阈值】桶 L1_age=young|L2_education=high|L3_hours-per-week=normal_hours（n_val=420，source=val) 使用本地阈值 α=0.7000, β=0.3000
# [INFO][BT][2026-03-26 15:29:56] 桶 bucket_id=L1_age=young|L2_education=high|L3_hours-per-week=normal_hours level=3：
#     n_train=989, n_val=420,
#     BAC=0.657, F1=0.500, AUC=0.952,
#     Regret=0.032, BND_ratio=0.031, POS_coverage=0.012,
#     Score(f1_regret_bnd )=nan，threshold_source=val
# [INFO][BT][2026-03-26 15:29:56] 桶 bucket_id=L1_age=young|L2_education=high|L3_hours-per-week=normal_hours：
#     parent_id=L1_age=young|L2_education=high，parent_Score=nan, bucket_Score=nan,
#     Gain=+nan, is_weak=False
# 【INFO】【2026-03-26 15:29:56】【阈值】桶 L1_age=young|L2_education=mid|L3_hours-per-week=high_hours（n_val=77，source=val) 使用本地阈值 α=0.2000, β=0.1000
# [INFO][BT][2026-03-26 15:29:56] 桶 bucket_id=L1_age=young|L2_education=mid|L3_hours-per-week=high_hours level=3：
#     n_train=190, n_val=77,
#     BAC=0.624, F1=0.500, AUC=0.923,
#     Regret=0.088, BND_ratio=0.091, POS_coverage=0.026,
#     Score(f1_regret_bnd )=nan，threshold_source=val
# [INFO][BT][2026-03-26 15:29:56] 桶 bucket_id=L1_age=young|L2_education=mid|L3_hours-per-week=high_hours：
#     parent_id=L1_age=young|L2_education=mid，parent_Score=nan, bucket_Score=nan,
#     Gain=+nan, is_weak=False
# 【INFO】【2026-03-26 15:29:56】【阈值】桶 L1_age=young|L2_education=mid|L3_hours-per-week=low_hours（n_val=417，source=val) 使用本地阈值 α=0.2000, β=0.1000
# [INFO][BT][2026-03-26 15:29:56] 桶 bucket_id=L1_age=young|L2_education=mid|L3_hours-per-week=low_hours level=3：
#     n_train=876, n_val=417,
#     BAC=0.500, F1=0.000, AUC=0.983,
#     Regret=0.004, BND_ratio=0.000, POS_coverage=0.000,
#     Score(f1_regret_bnd )=nan，threshold_source=val
# [INFO][BT][2026-03-26 15:29:56] 桶 bucket_id=L1_age=young|L2_education=mid|L3_hours-per-week=low_hours：
#     parent_id=L1_age=young|L2_education=mid，parent_Score=nan, bucket_Score=nan,
#     Gain=+nan, is_weak=False
# 【INFO】【2026-03-26 15:29:57】【阈值】桶 L1_age=young|L2_education=mid|L3_hours-per-week=normal_hours（n_val=438，source=val) 使用本地阈值 α=0.4000, β=0.3000
# [INFO][BT][2026-03-26 15:29:57] 桶 bucket_id=L1_age=young|L2_education=mid|L3_hours-per-week=normal_hours level=3：
#     n_train=1000, n_val=438,
#     BAC=1.000, F1=1.000, AUC=1.000,
#     Regret=0.000, BND_ratio=0.000, POS_coverage=0.009,
#     Score(f1_regret_bnd )=nan，threshold_source=val
# [INFO][BT][2026-03-26 15:29:57] 桶 bucket_id=L1_age=young|L2_education=mid|L3_hours-per-week=normal_hours：
#     parent_id=L1_age=young|L2_education=mid，parent_Score=nan, bucket_Score=nan,
#     Gain=+nan, is_weak=False
# 【INFO】【2026-03-26 15:29:57】【BTTWD】桶统计摘要：总桶数=61，非空桶=61，强桶=61，弱桶=0
# 【INFO】【2026-03-26 15:29:57】【BTTWD】共生成 42 个叶子桶，其中有效桶 0 个（已训练局部模型）
# 【INFO】【2026-03-26 15:29:57】【桶树】已为样本生成桶ID，共 48 个组合
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=mid|L2_education=high|L3_hours-per-week=high_hours：
#     assigned_samples=1100,
#     used_local_decision=1100,
#     fallback_to_parent=0,
#     parent_id=L1_age=mid|L2_education=high,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=mid|L2_education=high|L3_hours-per-week=low_hours：
#     assigned_samples=534,
#     used_local_decision=534,
#     fallback_to_parent=0,
#     parent_id=L1_age=mid|L2_education=high,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=mid|L2_education=high|L3_hours-per-week=normal_hours：
#     assigned_samples=2584,
#     used_local_decision=2584,
#     fallback_to_parent=0,
#     parent_id=L1_age=mid|L2_education=high,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=mid|L2_education=low|L3_hours-per-week=normal_hours：
#     assigned_samples=140,
#     used_local_decision=140,
#     fallback_to_parent=0,
#     parent_id=L1_age=mid|L2_education=low,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=mid|L2_education=low|L3_hours-per-week=others：
#     assigned_samples=73,
#     used_local_decision=73,
#     fallback_to_parent=0,
#     parent_id=L1_age=mid|L2_education=low,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=mid|L2_education=mid|L3_hours-per-week=high_hours：
#     assigned_samples=739,
#     used_local_decision=739,
#     fallback_to_parent=0,
#     parent_id=L1_age=mid|L2_education=mid,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=mid|L2_education=mid|L3_hours-per-week=low_hours：
#     assigned_samples=470,
#     used_local_decision=470,
#     fallback_to_parent=0,
#     parent_id=L1_age=mid|L2_education=mid,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=mid|L2_education=mid|L3_hours-per-week=normal_hours：
#     assigned_samples=2321,
#     used_local_decision=2321,
#     fallback_to_parent=0,
#     parent_id=L1_age=mid|L2_education=mid,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=mid|L2_education=top|L3_hours-per-week=high_hours：
#     assigned_samples=222,
#     used_local_decision=222,
#     fallback_to_parent=0,
#     parent_id=L1_age=mid|L2_education=top,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=mid|L2_education=top|L3_hours-per-week=normal_hours：
#     assigned_samples=259,
#     used_local_decision=259,
#     fallback_to_parent=0,
#     parent_id=L1_age=mid|L2_education=top,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=mid|L2_education=top|L3_hours-per-week=others：
#     assigned_samples=72,
#     used_local_decision=72,
#     fallback_to_parent=0,
#     parent_id=L1_age=mid|L2_education=top,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=old|L2_education=high|L3_hours-per-week=high_hours：
#     assigned_samples=1568,
#     used_local_decision=1568,
#     fallback_to_parent=0,
#     parent_id=L1_age=old|L2_education=high,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=old|L2_education=high|L3_hours-per-week=low_hours：
#     assigned_samples=549,
#     used_local_decision=549,
#     fallback_to_parent=0,
#     parent_id=L1_age=old|L2_education=high,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=old|L2_education=high|L3_hours-per-week=normal_hours：
#     assigned_samples=3211,
#     used_local_decision=3211,
#     fallback_to_parent=0,
#     parent_id=L1_age=old|L2_education=high,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=old|L2_education=low|L3_hours-per-week=normal_hours：
#     assigned_samples=212,
#     used_local_decision=212,
#     fallback_to_parent=0,
#     parent_id=L1_age=old|L2_education=low,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=old|L2_education=low|L3_hours-per-week=others：
#     assigned_samples=116,
#     used_local_decision=116,
#     fallback_to_parent=0,
#     parent_id=L1_age=old|L2_education=low,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=old|L2_education=mid|L3_hours-per-week=high_hours：
#     assigned_samples=916,
#     used_local_decision=916,
#     fallback_to_parent=0,
#     parent_id=L1_age=old|L2_education=mid,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=old|L2_education=mid|L3_hours-per-week=low_hours：
#     assigned_samples=537,
#     used_local_decision=537,
#     fallback_to_parent=0,
#     parent_id=L1_age=old|L2_education=mid,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=old|L2_education=mid|L3_hours-per-week=normal_hours：
#     assigned_samples=2713,
#     used_local_decision=2713,
#     fallback_to_parent=0,
#     parent_id=L1_age=old|L2_education=mid,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=old|L2_education=top|L3_hours-per-week=high_hours：
#     assigned_samples=566,
#     used_local_decision=566,
#     fallback_to_parent=0,
#     parent_id=L1_age=old|L2_education=top,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=old|L2_education=top|L3_hours-per-week=low_hours：
#     assigned_samples=126,
#     used_local_decision=126,
#     fallback_to_parent=0,
#     parent_id=L1_age=old|L2_education=top,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=old|L2_education=top|L3_hours-per-week=normal_hours：
#     assigned_samples=662,
#     used_local_decision=662,
#     fallback_to_parent=0,
#     parent_id=L1_age=old|L2_education=top,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=very_old|L2_education=high|L3_hours-per-week=high_hours：
#     assigned_samples=543,
#     used_local_decision=543,
#     fallback_to_parent=0,
#     parent_id=L1_age=very_old|L2_education=high,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=very_old|L2_education=high|L3_hours-per-week=low_hours：
#     assigned_samples=546,
#     used_local_decision=546,
#     fallback_to_parent=0,
#     parent_id=L1_age=very_old|L2_education=high,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=very_old|L2_education=high|L3_hours-per-week=normal_hours：
#     assigned_samples=1244,
#     used_local_decision=1244,
#     fallback_to_parent=0,
#     parent_id=L1_age=very_old|L2_education=high,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=very_old|L2_education=low|L3_hours-per-week=low_hours：
#     assigned_samples=170,
#     used_local_decision=170,
#     fallback_to_parent=0,
#     parent_id=L1_age=very_old|L2_education=low,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=very_old|L2_education=low|L3_hours-per-week=normal_hours：
#     assigned_samples=261,
#     used_local_decision=261,
#     fallback_to_parent=0,
#     parent_id=L1_age=very_old|L2_education=low,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=very_old|L2_education=low|L3_hours-per-week=others：
#     assigned_samples=80,
#     used_local_decision=80,
#     fallback_to_parent=0,
#     parent_id=L1_age=very_old|L2_education=low,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=very_old|L2_education=mid|L3_hours-per-week=high_hours：
#     assigned_samples=451,
#     used_local_decision=451,
#     fallback_to_parent=0,
#     parent_id=L1_age=very_old|L2_education=mid,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=very_old|L2_education=mid|L3_hours-per-week=low_hours：
#     assigned_samples=757,
#     used_local_decision=757,
#     fallback_to_parent=0,
#     parent_id=L1_age=very_old|L2_education=mid,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=very_old|L2_education=mid|L3_hours-per-week=normal_hours：
#     assigned_samples=1654,
#     used_local_decision=1654,
#     fallback_to_parent=0,
#     parent_id=L1_age=very_old|L2_education=mid,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=very_old|L2_education=top|L3_hours-per-week=high_hours：
#     assigned_samples=278,
#     used_local_decision=278,
#     fallback_to_parent=0,
#     parent_id=L1_age=very_old|L2_education=top,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=very_old|L2_education=top|L3_hours-per-week=low_hours：
#     assigned_samples=153,
#     used_local_decision=153,
#     fallback_to_parent=0,
#     parent_id=L1_age=very_old|L2_education=top,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=very_old|L2_education=top|L3_hours-per-week=normal_hours：
#     assigned_samples=323,
#     used_local_decision=323,
#     fallback_to_parent=0,
#     parent_id=L1_age=very_old|L2_education=top,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=young|L2_education=high|L3_hours-per-week=high_hours：
#     assigned_samples=291,
#     used_local_decision=291,
#     fallback_to_parent=0,
#     parent_id=L1_age=young|L2_education=high,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=young|L2_education=high|L3_hours-per-week=low_hours：
#     assigned_samples=1516,
#     used_local_decision=1516,
#     fallback_to_parent=0,
#     parent_id=L1_age=young|L2_education=high,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=young|L2_education=high|L3_hours-per-week=normal_hours：
#     assigned_samples=1409,
#     used_local_decision=1409,
#     fallback_to_parent=0,
#     parent_id=L1_age=young|L2_education=high,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=young|L2_education=low：
#     assigned_samples=146,
#     used_local_decision=146,
#     fallback_to_parent=0,
#     parent_id=L1_age=young,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=young|L2_education=mid|L3_hours-per-week=high_hours：
#     assigned_samples=267,
#     used_local_decision=267,
#     fallback_to_parent=0,
#     parent_id=L1_age=young|L2_education=mid,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=young|L2_education=mid|L3_hours-per-week=low_hours：
#     assigned_samples=1293,
#     used_local_decision=1293,
#     fallback_to_parent=0,
#     parent_id=L1_age=young|L2_education=mid,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=young|L2_education=mid|L3_hours-per-week=normal_hours：
#     assigned_samples=1438,
#     used_local_decision=1438,
#     fallback_to_parent=0,
#     parent_id=L1_age=young|L2_education=mid,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 预测统计：bucket_id=L1_age=young|L2_education=others：
#     assigned_samples=51,
#     used_local_decision=51,
#     fallback_to_parent=0,
#     parent_id=L1_age=young,
#     is_weak=False
# [INFO][BT][2026-03-26 15:30:00] 回退汇总：
#     总样本数=32561,
#     使用叶子桶决策的样本比例=100.000%,
#     使用中间桶决策的样本比例=0.000%,
#     回退到全局桶决策的样本比例=0.000%
# 【INFO】【2026-03-26 15:30:02】[t-SNE] Saved fallback_off embedding data to: e:\yan\组\三支决策\机器学习\BT_TWD\results\adult_bttwd\tsne_fallback\fallback_off_tsne_embedding.csv
# 【INFO】【2026-03-26 15:30:03】[t-SNE] Saved t-SNE embedding with mode labels: e:\yan\组\三支决策\机器学习\BT_TWD\results\adult_bttwd\tsne_fallback\tsne_fallback_embedding.csv
# e:\yan\组\三支决策\机器学习\BT_TWD\bttwdlib\tsne_visualizer.py:389: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# 【INFO】【2026-03-26 15:30:09】[t-SNE] Comparison figure saved to: e:\yan\组\三支决策\机器学习\BT_TWD\results\adult_bttwd\tsne_fallback\tsne_backoff_adult.png
# 【INFO】【2026-03-26 15:30:09】[t-SNE] Comparison figure saved to: e:\yan\组\三支决策\机器学习\BT_TWD\results\adult_bttwd\tsne_fallback\tsne_backoff_adult.pdf
# t-SNE 嵌入结果保存路径：e:\yan\组\三支决策\机器学习\BT_TWD\results\adult_bttwd\tsne_fallback\tsne_fallback_embedding.csv
# 弱桶对比摘要保存路径：e:\yan\组\三支决策\机器学习\BT_TWD\results\adult_bttwd\tsne_fallback\tsne_fallback_summary.csv
# 可视化图片保存路径：e:\yan\组\三支决策\机器学习\BT_TWD\results\adult_bttwd\tsne_fallback\tsne_backoff_adult.png
